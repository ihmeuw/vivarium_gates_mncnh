# %% [markdown]
# # V&V anemia screening and iron interventions
#
# This notebook focuses on anemia screening, oral iron, and IV iron.
#
# All the separate checks in this notebok are labeled with "CHECK" (all caps).

# %% [markdown]
# ## Setup

# %%
from vivarium.artifact import Artifact
from vivarium.engine import InteractiveContext
import pandas as pd, numpy as np, os
import matplotlib.pyplot as plt

# %%
! pip list | grep vivarium

# [software verion + hash . date]
# Out:
# 10291.91s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# vivarium-artifact                        1.1.0
# vivarium-build-utils                     4.6.0
# vivarium-cluster-tools                   4.6.0
# vivarium-config-tree                     5.2.0
# vivarium-dependencies                    1.3.0
# vivarium-engine                          5.8.1
# vivarium_gates_mncnh                     40.1.dev10+gc3dfbc8cd.d20260828 /mnt/share/homes/tylerdy/vivarium_gates_mncnh
# vivarium-gbd-mapping                     6.0.7
# vivarium-public-health                   6.6.0
# vivarium-risk-distributions              3.2.0
# vivarium-testing-utils                   0.7.6

# %%
! pip freeze | grep vivarium
# Out:
# 10298.96s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# vivarium-artifact==1.1.0
# vivarium-build-utils==4.6.0
# vivarium-cluster-tools==4.6.0
# vivarium-config-tree==5.2.0
# vivarium-dependencies==1.3.0
# vivarium-engine==5.8.1
# vivarium-gbd-mapping==6.0.7
# vivarium-public-health==6.6.0
# vivarium-risk-distributions==3.2.0
# vivarium-testing-utils==0.7.6
# -e git+https://github.com/ihmeuw/vivarium_gates_mncnh.git@004607513f8a6c93635f11463212205b8e4f2bbf#egg=vivarium_gates_mncnh

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from vivarium.artifact import Artifact
from vivarium.engine import InteractiveContext
from vivarium_gates_mncnh.constants import paths, data_values

# %%
import vivarium_gates_mncnh
from vivarium.engine.framework.configuration import build_model_specification
from pathlib import Path

path = Path(vivarium_gates_mncnh.__file__).parent / 'model_specifications/model_spec.yaml'
custom_model_specification = build_model_specification(path)
custom_model_specification.configuration.input_data.input_draw_number = 60

custom_model_specification.configuration.population.population_size =  20_000 * 3 # TODO: reset population and scenarios

# TODO: Remove (some) observers??
# del custom_model_specification.configuration.observers
# custom_model_specification.components.vivarium_gates_mncnh.components = [
#     c for c in custom_model_specification.components.vivarium_gates_mncnh.components
#     if 'observer' not in c.lower()
# ]

included_components = custom_model_specification.components.vivarium_gates_mncnh.components
included_components
# Out:
# ['Hemoglobin()',
#  'AnemiaInterventionPropensity()',
#  'RDSInterventionPropensity()',
#  'AgelessPopulation("population.scaling_factor")',
#  'Pregnancy()',
#  'ResultsStratifier()',
#  'ANCAttendance()',
#  'Ultrasound()',
#  'MaternalDisorder("maternal_obstructed_labor_and_uterine_rupture")',
#  'MaternalDisorder("maternal_sepsis_and_other_maternal_infections")',
#  'AntepartumHemorrhage()',
#  'PostpartumHemorrhage()',
#  'ResidualMaternalDisorders()',
#  'AbortionMiscarriageEctopicPregnancy()',
#  'MaternalDisordersBurden()',
#  'LBWSGRisk()',
#  "LBWSGRiskEffect('cause.all_causes.all_cause_mortality_risk')",
#  "LBWSGRiskEffect('cause.neonatal_sepsis_and_other_neonatal_infections.cause_specific_mortality_risk')",
#  "LBWSGRiskEffect('cause.neonatal_preterm_birth_with_rds.cause_specific_mortality_risk')",
#  "LBWSGRiskEffect('cause.neonatal_preterm_birth_without_rds.cause_specific_mortality_risk')",
# ...

# %%
artifact_path = custom_model_specification.configuration.input_data.artifact_path
art = Artifact(artifact_path)
location = Path(custom_model_specification.configuration.input_data.artifact_path).stem

artifact_path
# Out:
# '/mnt/team/simulation_science/pub/models/vivarium_gates_mncnh/artifacts/model40.1/ethiopia.hdf'

# %%
draw_num = custom_model_specification.configuration.input_data.input_draw_number
draw = 'draw_' + str(draw_num)
draw
# Out:
# 'draw_60'

# %% [markdown]
# CHECK: IFA coverage in the artifact does not vary by sex, age, or year.
#
# Suite: artifact tests.
#
# Type: precise assert.

# %%
ifa_coverage_at_anc = art.load('risk_factor.iron_folic_acid_supplementation.coverage')[draw]
assert (ifa_coverage_at_anc.groupby('parameter').nunique() == 1).all()
ifa_coverage_at_anc = ifa_coverage_at_anc.groupby('parameter').first()
# ok, so following the update,
    # cat1: uncovered
    # cat2: covered
ifa_coverage_at_anc = ifa_coverage_at_anc.loc['cat2']
ifa_coverage_at_anc
# Out:
# np.float64(0.6131486122585059)

# %% [markdown]
# CHECK: ANC1 coverage in the artifact does not vary by sex, age, or year.
#
# Suite: artifact tests.
#
# Type: precise assert.

# %%
anc1 = art.load('covariate.antenatal_care_1_visit_coverage_proportion.estimate')[draw]
assert len(anc1) == 1
anc1 = anc1.values[0]
ifa_coverage = ifa_coverage_at_anc * anc1
ifa_coverage
# Out:
# np.float64(0.4614656393260721)

# %%
ifa_effect = art.load('risk_factor.iron_folic_acid_supplementation.effect_size')[draw]
ifa_effect_hgb = ifa_effect['hemoglobin.exposure']
ifa_effect_hgb
# Out:
# np.float64(9.922280818201326)

# %% [markdown]
# CHECK: IV iron's effect on hemoglobin in the artifact does not vary by sex, age, or year.
#
# Suite: artifact tests.
#
# Type: precise assert.

# %%
iv_iron_effect_hgb = art.load('intervention.iv_iron.hemoglobin_effect_size')[draw]
assert len(iv_iron_effect_hgb) == 1
iv_iron_effect_hgb = iv_iron_effect_hgb.iloc[0]
iv_iron_effect_hgb
# Out:
# np.float64(21.65971411676581)

# %%
# NOTE: "Risk-specific shift" is being used analogously to "cause-specific mortality rate" (which is already used
# a bit weirdly in VPH) to mean "baseline deletion amount"
ifa_ga_deletion_shift = art.load('risk_factor.iron_folic_acid_supplementation.risk_specific_shift')[draw]
ifa_ga_deletion_shift = ifa_ga_deletion_shift[ifa_ga_deletion_shift.index.get_level_values('affected_entity') == 'gestational_age']
assert ifa_ga_deletion_shift.nunique() == 1
ifa_ga_deletion_shift = ifa_ga_deletion_shift.iloc[0]
ifa_ga_deletion_shift
# Out:
# np.float64(0.0641060920641154)

# %%
ifa_ga_shift = art.load('risk_factor.iron_folic_acid_supplementation.excess_shift')[draw]
ifa_ga_shift = ifa_ga_shift[ifa_ga_shift.index.get_level_values('affected_entity') == 'gestational_age']
assert (ifa_ga_shift.groupby('parameter').nunique() == 1).all()
ifa_ga_shift = ifa_ga_shift.groupby('parameter').first().loc['cat2'] # cat2 == covered
ifa_ga_shift
# Out:
# np.float64(0.1389184515617163)

# %%
ifa_ga_shift_anc = art.load("risk_factor.iron_folic_acid_supplementation.excess_gestational_age_shift_anc")[draw]
ifa_ga_shift_anc = ifa_ga_shift_anc[ifa_ga_shift_anc.index.get_level_values('affected_entity') == 'gestational_age']
assert (ifa_ga_shift_anc.groupby('parameter').nunique() == 1).all()
ifa_ga_shift_anc = ifa_ga_shift_anc.groupby('parameter').first().loc['cat2'] # cat2 == covered

ifa_ga_shift_non_anc = art.load("risk_factor.iron_folic_acid_supplementation.excess_gestational_age_shift_non_anc")[draw]
ifa_ga_shift_non_anc = ifa_ga_shift_non_anc[ifa_ga_shift_non_anc.index.get_level_values('affected_entity') == 'gestational_age']
assert (ifa_ga_shift_non_anc.groupby('parameter').nunique() == 1).all()
ifa_ga_shift_non_anc = ifa_ga_shift_non_anc.groupby('parameter').first().loc['cat2'] # cat2 == covered

anc_proportion = art.load('covariate.antenatal_care_1_visit_coverage_proportion.estimate')[draw]
assert len(anc_proportion) == 1
anc_proportion = anc_proportion.values[0]
assert np.isclose(
    ifa_ga_shift_anc * anc_proportion + ifa_ga_shift_non_anc * (1 - anc_proportion),
    ifa_ga_shift,
    rtol=0,
    atol=1e-6,
), "The weighted average of the anc and non-anc shifts should equal the overall shift"

assert np.isclose(
    ifa_coverage_at_anc * ifa_ga_shift * anc_proportion,
    ifa_ga_deletion_shift,
    rtol=0,
    atol=1e-6,
), "The product of coverage, shift, and ANC proportion should equal the deletion shift"

# %%
mms_ga_shift = pd.concat([
    art.load('risk_factor.multiple_micronutrient_supplementation.excess_gestational_age_shift_subpop_1')[draw].to_frame().assign(very_preterm_baseline=True).set_index('very_preterm_baseline', append=True)[draw],
    art.load('risk_factor.multiple_micronutrient_supplementation.excess_gestational_age_shift_subpop_2')[draw].to_frame().assign(very_preterm_baseline=False).set_index('very_preterm_baseline', append=True)[draw],
])
assert (mms_ga_shift.index.get_level_values('affected_entity') == 'gestational_age').all()
assert (mms_ga_shift.groupby(['parameter', 'very_preterm_baseline']).nunique() == 1).all()
mms_ga_shift = mms_ga_shift.groupby(['parameter', 'very_preterm_baseline']).first().loc['cat2'] # cat2 == covered
mms_ga_shift
# Out:
# very_preterm_baseline
# False    0.327645
# True     0.597466
# Name: draw_60, dtype: float64

# %%
mms_stillbirth_rr = art.load('risk_factor.multiple_micronutrient_supplementation.stillbirth_rr')[draw]
assert len(mms_stillbirth_rr) == 1
mms_stillbirth_rr = mms_stillbirth_rr.iloc[0]
mms_stillbirth_rr
# Out:
# np.float64(0.8982709656618421)

# %% [markdown]
# CHECK: Relative risks of hemoglobin in the artifact do not vary by sex, age, or year.
#
# Suite: artifact tests.
#
# Type: precise assert.

# %%
art_rrs = art.load('risk_factor.hemoglobin.relative_risk').reset_index()
exposure_levels = art_rrs.parameter.unique()
tmrel = exposure_levels[len([x for x in exposure_levels if x < 120])]
art_tmrel = art_rrs.loc[art_rrs.parameter == tmrel].drop(columns='parameter')
art_rrs = (art_rrs.set_index([x for x in art_rrs.columns if 'draw' not in x])
          / art_tmrel.set_index([x for x in art_tmrel.columns if 'draw' not in x])).reset_index()
assert (art_rrs.groupby(['affected_entity', 'parameter'])[draw].nunique() == 1).all()
art_rrs = art_rrs.groupby(['affected_entity', 'parameter'])[draw].first()
art_rrs
# Out:
# affected_entity        parameter
# maternal_hemorrhage    40.00000     5.531382
#                        40.11011     5.524832
#                        40.22022     5.518280
#                        40.33033     5.511725
#                        40.44044     5.505168
#                                       ...
# postpartum_depression  149.55956    0.978076
#                        149.66967    0.978083
#                        149.77978    0.978090
#                        149.88989    0.978098
#                        150.00000    0.978105
# Name: draw_60, Length: 4000, dtype: float64

# %%
art_rrs.index.get_level_values('affected_entity').unique()
# Out:
# Index(['maternal_hemorrhage', 'maternal_hypertensive_disorders',
#        'maternal_sepsis_and_other_maternal_infections',
#        'postpartum_depression'],
#       dtype='str', name='affected_entity')

# %% [markdown]
# CHECK: Probability of low ferritin in the artifact in the 'not_anemic' category is always half of the corresponding value in the 'mild' category.
#
# Suite: artifact tests.
#
# Type: precise assert.

# %%
art_low_ferritin_probs = art.load('ferritin.probability_of_low_ferritin')[draw]
# https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/anemia_screening.html#id6
assert np.allclose(
    art_low_ferritin_probs.loc[(slice(None), slice(None), 'not_anemic')],
    art_low_ferritin_probs.loc[(slice(None), slice(None), 'mild')] / 2,
)
art_low_ferritin_probs

# I might have expected that more people would have low ferritin in the more extreme anemias, but it is actually the opposite
# Out:
# age_start  age_end  anemia_status_during_pregnancy
# 10.0       15.0     mild                              0.913531
#                     moderate                          0.838612
#                     not_anemic                        0.456765
#                     severe                            0.759654
# 15.0       20.0     mild                              0.852187
#                     moderate                          0.778244
#                     not_anemic                        0.426094
#                     severe                            0.735942
# 20.0       25.0     mild                              0.857813
#                     moderate                          0.785119
#                     not_anemic                        0.428906
#                     severe                            0.736791
# 25.0       30.0     mild                              0.856926
#                     moderate                          0.780867
# ...

# %%
art_iv_iron_sb_rr = art.load('intervention.iv_iron.stillbirth_relative_risk')[draw].rename('val')
art_iv_iron_lbwsg_shifts = art.load('intervention.iv_iron.low_birth_weight_and_short_gestation_effect_size')[draw]

# %% [markdown]
# ## Create simulations
#
# Run all four scenarios (baseline, mms_total_scaleup, anemia_screening_vv, anemia_screening_and_iv_iron_scaleup) in sync, checking within-scenario and cross-scenario invariants at each timestep.

# %%
from copy import deepcopy

def anemia_status_from_hemoglobin(hemoglobin, thresholds=None):
    # https://github.com/ihmeuw/vivarium_gates_mncnh/blob/98980208ebcf8c4f19fa121f6ca20eba56357840/src/vivarium_gates_mncnh/components/screening.py#L90
    # Pregnancy anemia thresholds by default; late postpartum (6w-9m) uses
    # non-pregnancy thresholds [80, 110, 120] (mirrors observer get_anemia_status_from_hemoglobin).
    if thresholds is None:
        thresholds = [70, 100, 110]
    return (
        pd.cut(
            hemoglobin,
            bins=[-np.inf, *thresholds],
            labels=["severe", "moderate", "mild"],
            right=False,
        )
        .astype("object")
        .fillna("not_anemic")
        .astype(pd.CategoricalDtype(["severe", "moderate", "mild", "not_anemic"], ordered=True))
    )

# https://vivarium-research.readthedocs.io/en/latest/models/other_models/hemoglobin_anemia_and_iron_deficiency/anemia_impairment/index.html#id6
anemia_status_to_dw = {
    "severe": 0.149,
    "moderate": 0.052,
    "mild": 0.004,
    "not_anemic": 0.0,
}

scenarios = ['baseline', 'anemia_screening_and_iv_iron_scaleup']# ['baseline', 'mms_total_scaleup', 'anemia_screening_vv', 'anemia_screening_and_iv_iron_scaleup']
sims = {}
sim_step_names = {}
hemoglobin_components = {}

for scenario in scenarios:
    spec = deepcopy(custom_model_specification)
    spec.configuration.intervention.scenario = scenario
    # observe=True: InteractiveContext does not observe results by default, and
    # the checks below read sim.get_results().
    sim = InteractiveContext(spec, observe=True)
    sims[scenario] = sim
    hgb_comp = sim.list_components()['risk_factor.hemoglobin']
    hemoglobin_components[scenario] = hgb_comp
    sim_step_names[scenario] = hgb_comp._sim_step_name
    sim_step_names[scenario]()  # Initialize

print(f"Created {len(scenarios)} simulations: {', '.join(scenarios)}")
# Out:
# 2026-09-17 11:38:13.149 | 2:50:59.278044 | WARNING  | simulation_3-values_manager:_warn_if_overriding_resources:465 - Conflicting information for birth_outcome_probabilities. Ignoring 'required_resources' since the `source` is of type <class 'vivarium.engine.framework.lookup.table.LookupTable'> and we can infer the required resources directly.
# 2026-09-17 11:38:16.567 | 2:51:02.696204 | WARNING  | simulation_3-values_manager:_warn_if_overriding_resources:465 - Conflicting information for lbwsg_paf_on_all_causes.all_cause_mortality_risk.paf. Ignoring 'required_resources' since the `source` is of type <class 'vivarium.engine.framework.lookup.table.LookupTable'> and we can infer the required resources directly.
# ...

# %% [markdown]
# ## Initialization checks
#
# Before first step:
#
# * CHECK: ANC attendance column starts as all null.
# * CHECK: Oral iron column starts as all 'no_treatment'.
# * CHECK: Each simulant's hemoglobin value should be lower than their 'raw_hemoglobin' value (the simulant's draw from the GBD distribution) by baseline IFA coverage times the IFA effect on hemoglobin.

# %%
raw_hemoglobins = {}
initial_hemoglobins = {}

for scenario in scenarios:
    sim = sims[scenario]
    hgb_comp = hemoglobin_components[scenario]

    pop = sim.get_population(['anc_attendance', 'oral_iron_intervention'])
    assert pop.anc_attendance.isnull().all(), f"{scenario}: ANC attendance not null at init"
    assert (pop.oral_iron_intervention == 'no_treatment').all(), f"{scenario}: oral iron not no_treatment at init"

    # https://github.com/ihmeuw/vivarium_public_health/blob/3b2b4f13ef53c0e9fd378e824eeb81a9057fea8d/src/vivarium_public_health/risks/base_risk.py#L303-L305
    raw_hemoglobins[scenario] = hgb_comp.exposure_distribution.exposure_ppf(
        pop.index
    ).rename('raw_hemoglobin')
    initial_hemoglobins[scenario] = sim.get_population('hemoglobin.exposure').rename('initial_hemoglobin')

    if 'OralIronEffectOnHemoglobin()' in included_components:
        assert np.allclose(
            raw_hemoglobins[scenario] - initial_hemoglobins[scenario],
            ifa_coverage * ifa_effect_hgb,
            rtol=0,
            atol=1e-7,
        ), f"{scenario}: IFA deletion does not match expectation from recalculation"
    else:
        assert np.allclose(
            raw_hemoglobins[scenario],
            initial_hemoglobins[scenario],
            rtol=0,
            atol=1e-7,
        ), f"{scenario}: raw hemoglobin does not match initial hemoglobin when no IFA effect expected"

print("All initialization checks passed.")
# Out:
# All initialization checks passed.

# %% [markdown]
# ## First trimester ANC
#
# After first-trimester ANC timestep:
#
# * CHECK: ANC attendance column all non-null.
# * CHECK: Oral iron column remains 'no_treatment' for simulants who did not attend first-trimester ANC.
# * CHECK: Oral iron column all 'mms' for simulants who did attend first-trimester ANC, in an MMS scale-up scenario.
# * CHECK: Oral iron column a mix of 'ifa' and 'no_treatment' in non-MMS scale-up scenarios.
# * CHECK: In non-MMS scale-up scenarios, proportion of those attending first-trimester ANC who received IFA should match IFA coverage from artifact. Type: fuzzy check of proportion.
# * CHECK: Simulants who received IFA or MMS on this timestep should have had their hemoglobin value increased by the IFA effect (shared by MMS), relative to the previous timestep.
# * CHECK: Simulants who did not receive oral iron on this timestep should have the same hemoglobin they had on the previous timestep.
# * CHECK: Hemoglobin and ferritin screening coverage columns are all null (stay that way until the screening timestep).
#
# Cross-scenario:
#
# * CHECK: The same simulants attend ANC (in each ANC attendance category) in all scenarios.

# %%
first_trimester_pops = {}
first_trimester_hemoglobins = {}
first_anc_times = {}
recorded_anemia_ylds = {}
recorded_anemia_person_time = {}

for scenario in scenarios:
    sim = sims[scenario]
    assert sim_step_names[scenario]() == "first_trimester_anc", f"{scenario}: expected first_trimester_anc step"
    sim.step()

    pop = sim.get_population([
        'anc_attendance', 'oral_iron_intervention', 'time_of_first_anc_visit',
        'hemoglobin_screening_coverage', 'ferritin_screening_coverage',
        'anemia_status_during_pregnancy',
    ])

    # CHECK: ANC attendance non-null
    assert pop.anc_attendance.notnull().all(), f"{scenario}: ANC attendance null after first_trimester_anc"
    # CHECK: No oral iron for non-first-trimester ANC attenders
    assert (pop[
        pop.anc_attendance.isin(['none', 'later_pregnancy_only'])
    ].oral_iron_intervention == 'no_treatment').all(), f"{scenario}: IFA before screening for non-first-trimester ANC attenders"

    # CHECK: Anemia person-time
    anemia_status = anemia_status_from_hemoglobin(initial_hemoglobins[scenario])
    first_anc_times[scenario] = (pop.time_of_first_anc_visit / pd.Timedelta(days=365.25)).fillna(6 / 52)
    recorded_anemia_person_time[scenario] = sim.get_results()['anemia_person_time']
    assert np.allclose(
        first_anc_times[scenario].groupby(anemia_status).sum().sort_index(),
        recorded_anemia_person_time[scenario].groupby('anemia_status').value.sum().sort_index(),
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: early ANC timestep anemia person-time does not match recalculation"

    # CHECK: Anemia YLDs
    dw = anemia_status.map(anemia_status_to_dw).astype(float)
    recorded_anemia_ylds[scenario] = sim.get_results()['anemia_ylds']
    assert np.allclose(
        (dw * first_anc_times[scenario]).groupby(anemia_status).sum().sort_index(),
        recorded_anemia_ylds[scenario].groupby('anemia_status').value.sum().sort_index(),
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: early ANC timestep anemia YLDs do not match recalculation"

    # CHECK: Scenario-specific oral iron coverage
    early_anc_attenders = ~pop.anc_attendance.isin(['none', 'later_pregnancy_only'])
    if scenario == 'mms_total_scaleup':
        assert (
            pop.loc[early_anc_attenders, 'oral_iron_intervention'] == 'mms'
        ).all(), f"{scenario}: MMS not fully scaled up!"
    else:
        print(f'{scenario} - Target IFA coverage at ANC: {ifa_coverage_at_anc}')
    print(f'{scenario} - Simulated oral iron coverage at ANC in first trimester:')
    display(pop.loc[early_anc_attenders].oral_iron_intervention.value_counts(normalize=True))

    # Augment pop with hemoglobin data
    # Both APH and PPH share the same RR data (keyed as "maternal_hemorrhage" in the artifact)
    hemoglobin_exposure = sim.get_population('hemoglobin.exposure').rename('hemoglobin_exposure')
    aph_rr = sim.get_population('hemoglobin_on_antepartum_hemorrhage.incidence_risk.relative_risk')
    pph_rr = sim.get_population('hemoglobin_on_postpartum_hemorrhage.incidence_risk.relative_risk')
    pop = pd.concat([
        pop,
        raw_hemoglobins[scenario],
        initial_hemoglobins[scenario],
        hemoglobin_exposure,
        aph_rr,
        pph_rr,
    ], axis=1)

    print(f'{scenario} - Mean hemoglobin exposure: GBD vs after first trimester ANC in sim')
    display(pop[['raw_hemoglobin', 'hemoglobin_exposure']].mean())

    # CHECK: Hemoglobin effects from oral iron
    if 'OralIronEffectOnHemoglobin()' in included_components:
        if scenario in ('baseline', 'anemia_screening_vv', 'anemia_screening_and_iv_iron_scaleup'):
            # hemoglobin exposure is still lower at this point than GBD estimates, because not all IFA has been applied
            assert pop['hemoglobin_exposure'].mean() < pop['raw_hemoglobin'].mean(), \
            f"{scenario}: hemoglobin exposure not lower than raw"
        elif scenario == 'mms_full_scaleup':
            # There's not a clear target for whether this should be lower or higher,
            # since not all oral iron has been applied yet, but MMS has been scaled up to 100% of early ANC visits
            pass

        assert np.allclose(
            pop.loc[pop.oral_iron_intervention != 'no_treatment', 'hemoglobin_exposure'] -
            pop.loc[pop.oral_iron_intervention != 'no_treatment', 'initial_hemoglobin'],
            ifa_effect_hgb,
            rtol=0,
            atol=1e-7,
        ), f"{scenario}: Oral iron effect does not match expectation from recalculation"

        assert (
            pop.loc[pop.oral_iron_intervention == 'no_treatment', 'hemoglobin_exposure'] ==
            pop.loc[pop.oral_iron_intervention == 'no_treatment', 'initial_hemoglobin']
        ).all(), f"{scenario}: hemoglobin modified in simulants not receiving oral iron"

        assert np.allclose(
            pop['raw_hemoglobin'] - pop['initial_hemoglobin'],
            ifa_coverage * ifa_effect_hgb,
            rtol=0,
            atol=1e-7,
        ), f"{scenario}: IFA deletion does not match expectation from recalculation"
    else:
        assert (
            pop['raw_hemoglobin'] ==
            pop['initial_hemoglobin']
        ).all(), f"{scenario}: IFA deletion when oral iron effect is not included"

        assert (
            pop['hemoglobin_exposure'] ==
            pop['initial_hemoglobin']
        ).all(), f"{scenario}: hemoglobin modified at early ANC when oral iron effect is not included"

    assert (
        pop.loc[pop.oral_iron_intervention == 'no_treatment', 'hemoglobin_exposure'] ==
        pop.loc[pop.oral_iron_intervention == 'no_treatment', 'initial_hemoglobin']
    ).all(), f"{scenario}: hemoglobin modified in simulants not receiving oral iron"

    # CHECK: No screening yet
    assert (~pop.filter(like='screening_coverage')).all().all(), f"{scenario}: Screening occurred before screening timestep"
    assert pop.anemia_status_during_pregnancy.isnull().all(), f"{scenario}: Anemia status during pregnancy assigned before screening timestep"

    first_trimester_pops[scenario] = pop
    first_trimester_hemoglobins[scenario] = hemoglobin_exposure

# Cross-scenario check: same ANC attendance in all scenarios
for s in scenarios[1:]:
    assert (
        first_trimester_pops['baseline'].anc_attendance == first_trimester_pops[s].anc_attendance
    ).all(), f"ANC attendance differs between baseline and {s}"
print("\nCross-scenario: ANC attendance matches across all scenarios.")
# Out:
# baseline - Target IFA coverage at ANC: 0.6131486122585059
# baseline - Simulated oral iron coverage at ANC in first trimester:
# oral_iron_intervention
# ifa             0.615221
# no_treatment    0.384779
# Name: proportion, dtype: float64
# baseline - Mean hemoglobin exposure: GBD vs after first trimester ANC in sim
# raw_hemoglobin         119.356909
# hemoglobin_exposure    117.367502
# dtype: float64
# anemia_screening_and_iv_iron_scaleup - Target IFA coverage at ANC: 0.6131486122585059
# anemia_screening_and_iv_iron_scaleup - Simulated oral iron coverage at ANC in first trimester:
# oral_iron_intervention
# ifa             0.615221
# no_treatment    0.384779
# Name: proportion, dtype: float64
# anemia_screening_and_iv_iron_scaleup - Mean hemoglobin exposure: GBD vs after first trimester ANC in sim
# raw_hemoglobin         119.356909
# hemoglobin_exposure    117.367502
# dtype: float64
# Cross-scenario: ANC attendance matches across all scenarios.

# %% [markdown]
# ## Later pregnancy screening
#
# After later-pregnancy screening timestep:
#
# * CHECK: In non-screening-scale-up scenarios, there is non-zero hemoglobin screening.
# * CHECK: In screening scale-up scenarios, the simulants with hemoglobin screening coverage are exactly those who attend later-pregnancy ANC.
# * CHECK: The proportion of simulants with truly low hemoglobin (hemoglobin <100) who test low (out of those who test) is approximately the documented 85% sensitivity. Type: fuzzy check of proportion.
# * CHECK: The proportion of simulants with truly adequate hemoglobin (hemoglobin >= 100) who test adequate (out of those who test) is approximately the documented 80% specificity. Type: fuzzy check of proportion.
# * CHECK: In non-screening-scale-up scenarios, there is zero ferritin screening.
# * CHECK: In screening scale-up scenarios, the simulants with ferritin screening coverage are exactly those who test low hemoglobin.
# * CHECK: The proportion of simulants who test low ferritin (out of those who are tested) matches the target in the artifact (by age and anemia status). Type: fuzzy check of proportion.

# %%
pops_after_screening = {}

for scenario in scenarios:
    sim = sims[scenario]
    assert sim_step_names[scenario]() == "later_pregnancy_screening", f"{scenario}: expected later_pregnancy_screening step"
    sim.step()

    pop = sim.get_population([
        'anc_attendance', 'oral_iron_intervention', 'age',
        'hemoglobin_screening_coverage', 'ferritin_screening_coverage',
        'tested_hemoglobin', 'tested_ferritin', 'anemia_status_during_pregnancy',
    ])
    hemoglobin_exposure = sim.get_population('hemoglobin.exposure').rename('hemoglobin_exposure')
    pop = pd.concat([pop, hemoglobin_exposure], axis=1)

    # CHECK: Non-zero hemoglobin screening
    assert pop["hemoglobin_screening_coverage"].any(), f"{scenario}: No baseline hemoglobin screening"

    if scenario in ('baseline', 'mms_total_scaleup'):
        assert not pop["ferritin_screening_coverage"].any(), f"{scenario}: Ferritin screening when not scaled up"
    elif scenario in ('anemia_screening_vv', 'anemia_screening_and_iv_iron_scaleup'):
        assert pop[~pop.anc_attendance.isin(['none', 'first_trimester_only'])].hemoglobin_screening_coverage.all()
        # NOTE: ferritin_screening_coverage column is not correct!
        assert (
            (pop.tested_hemoglobin == 'low')
            ==
            (pop.tested_ferritin != 'not_tested')
        ).all(), f"{scenario}: Ferritin screening not fully scaled up, or applied to those not testing low hemoglobin!"
        # NOTE: anemia_status_during_pregnancy column is not updated!
        anemia_status_during_pregnancy = anemia_status_from_hemoglobin(pop['hemoglobin_exposure'])
        age_cutoffs = sorted(list(
            set(art_low_ferritin_probs.index.get_level_values('age_start')) |
            set(art_low_ferritin_probs.index.get_level_values('age_end'))
        ))
        age_groups = pd.cut(pop['age'], bins=age_cutoffs, right=False)
        sim_ferritin_results = (
            pop.assign(
                anemia_status_during_pregnancy=anemia_status_during_pregnancy,
                age_start=age_groups.cat.categories.left[age_groups.cat.codes],
                age_end=age_groups.cat.categories.right[age_groups.cat.codes],
            )
                [pop.tested_ferritin != 'not_tested']
                .groupby(['age_start', 'age_end', 'anemia_status_during_pregnancy'])
                .tested_ferritin.value_counts(normalize=True).loc[(slice(None), slice(None), slice(None), 'low')]
        )
        comparison = art_low_ferritin_probs.rename('target').to_frame().join(sim_ferritin_results.rename('sim'))
        print(f'{scenario} - Percent of those tested who have low ferritin:')
        display(comparison)

    # https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/anemia_screening.html#hemoglobin-screening-accuracy-instructions
    print(f'{scenario} - Specificity target (percent of true negatives that test negative): 80%')
    print('Observed:')
    display(pop[
        (pop.hemoglobin_exposure > 100) &
        (pop.hemoglobin_screening_coverage)
    ].tested_hemoglobin.value_counts(dropna=False, normalize=True))

    print(f'{scenario} - Sensitivity target (percent of true positives that test positive): 85%')
    print('Observed:')
    display(pop[
        (pop.hemoglobin_exposure < 100) &
        (pop.hemoglobin_screening_coverage)
    ].tested_hemoglobin.value_counts(dropna=False, normalize=True))

    pops_after_screening[scenario] = pop
# Out:
# baseline - Specificity target (percent of true negatives that test negative): 80%
# Observed:
# tested_hemoglobin
# adequate    0.802949
# low         0.197051
# Name: proportion, dtype: float64
# baseline - Sensitivity target (percent of true positives that test positive): 85%
# Observed:
# tested_hemoglobin
# low         0.857398
# adequate    0.142602
# Name: proportion, dtype: float64
# anemia_screening_and_iv_iron_scaleup - Percent of those tested who have low ferritin:
#                                                     target       sim
# age_start age_end anemia_status_during_pregnancy
# 10.0      15.0    mild                            0.913531  1.000000
#                   moderate                        0.838612  0.958333
#                   not_anemic                      0.456765  0.384615
#                   severe                          0.759654  1.000000
# 15.0      20.0    mild                            0.852187  0.833333
# ...

# %% [markdown]
# ## Later pregnancy intervention
#
# After later-pregnancy intervention timestep:
#
# * CHECK: In non-MMS-scaleup scenarios, the only change to oral iron coverage vs the previous timestep is some later-pregnancy-only-ANC-attending simulants shifting from 'none' to 'ifa'.
# * CHECK: In MMS-scaleup scenarios, the only change to oral iron coverage vs the previous timestep is some later-pregnancy-only-ANC-attending simulants shifting from 'none' to 'mms'.
# * CHECK: No IV iron received in non-IV-iron scaleup scenarios.
# * CHECK: In IV-iron scaleup scenarios, IV iron received by exactly the simulants who test low ferritin.
# * CHECK: Hemoglobin unchanged from previous timestep for simulants who neither changed oral iron coverage on this timestep, nor received IV iron.
# * CHECK: Hemoglobin increased vs previous timestep in those who received IV iron by the IV iron effect size on hemoglobin.
# * CHECK: Hemoglobin increased vs previous timestep in those who received new oral iron and did NOT receive IV iron by the IFA effect size on hemoglobin.

# %%
screening_step_hemoglobins = {}
hemoglobin_after_intervention = {}

for scenario in scenarios:
    sim = sims[scenario]
    screening_step_hemoglobins[scenario] = sim.get_population('hemoglobin.exposure')

    assert sim_step_names[scenario]() == 'later_pregnancy_intervention', f"{scenario}: expected later_pregnancy_intervention step"
    sim.step()

    pop = sim.get_population([
        'oral_iron_intervention', 'iv_iron_intervention', 'anc_attendance',
        'tested_ferritin',
    ])

    # CHECK: Oral iron changes
    oral_iron_changed = pop.oral_iron_intervention != pops_after_screening[scenario].oral_iron_intervention
    later_oral_iron_changes = pd.DataFrame({
        'oral_iron_before': pops_after_screening[scenario][oral_iron_changed].oral_iron_intervention,
        'oral_iron_after': pop[oral_iron_changed].oral_iron_intervention,
    })
    assert (later_oral_iron_changes.oral_iron_before == 'no_treatment').all()
    if scenario in ('baseline', 'anemia_screening_vv', 'anemia_screening_and_iv_iron_scaleup'):
        assert (later_oral_iron_changes.oral_iron_after == 'ifa').all()
    elif scenario == 'mms_total_scaleup':
        assert (later_oral_iron_changes.oral_iron_after == 'mms').all()
    print(f'{scenario} - Oral iron changes at later ANC:')
    display(later_oral_iron_changes)

    assert (pops_after_screening[scenario][oral_iron_changed].anc_attendance == 'later_pregnancy_only').all()

    # CHECK: IV iron
    iv_iron_received = pop.iv_iron_intervention == 'covered'
    if scenario in ('baseline', 'mms_total_scaleup', 'anemia_screening_vv'):
        assert not iv_iron_received.any(), f"{scenario}: baseline IV iron"
    elif scenario == 'anemia_screening_and_iv_iron_scaleup':
        assert (
            (pop.tested_ferritin == 'low') == iv_iron_received
        ).all(), f"{scenario}: IV iron not fully scaled up, or given to people who did not test low ferritin"
        assert np.sum(iv_iron_received) > 0, "simulants should receive IV iron"
        assert iv_iron_effect_hgb > 0, "iv iron should have a positive effect on hgb"
        display(f"{np.sum(iv_iron_received)} simulants received iv_iron in scaleup scenario")
        display((sim.get_population('hemoglobin.exposure')[iv_iron_received] - sims['baseline'].get_population('hemoglobin.exposure')[iv_iron_received]).value_counts())

    assert pops_after_screening[scenario][iv_iron_received].anc_attendance.isin(
        ['first_trimester_and_later_pregnancy', 'later_pregnancy_only']
    ).all()

    # CHECK: Hemoglobin changes
    hemoglobin_after = sim.get_population('hemoglobin.exposure')

    assert (
        screening_step_hemoglobins[scenario][~oral_iron_changed & ~iv_iron_received] ==
        hemoglobin_after[~oral_iron_changed & ~iv_iron_received]
    ).all(), f"{scenario}: Hemoglobin exposure changed at later intervention timestep for those not receiving later intervention"

    if 'OralIronEffectOnHemoglobin()' in included_components:
        assert np.allclose(
            hemoglobin_after[oral_iron_changed & ~iv_iron_received] -
            screening_step_hemoglobins[scenario][oral_iron_changed & ~iv_iron_received],
            ifa_effect_hgb,
            rtol=0,
            atol=1e-7,
        ), "IFA effect does not match expectation from recalculation"
    else:
        assert (
            screening_step_hemoglobins[scenario][oral_iron_changed & ~iv_iron_received] ==
            hemoglobin_after[oral_iron_changed & ~iv_iron_received]
        ).all(), "Oral iron effect when not included in model"

    assert np.allclose(
        hemoglobin_after[~oral_iron_changed & iv_iron_received] -
        screening_step_hemoglobins[scenario][~oral_iron_changed & iv_iron_received],
        iv_iron_effect_hgb,
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: IV iron effect does not match expectation from recalculation"

    # https://vivarium-research.readthedocs.io/en/latest/models/concept_models/vivarium_mncnh_portfolio/hemoglobin_module/module_document.html#end-of-pregnancy-hemoglobin-module
    assert np.allclose(
        hemoglobin_after[oral_iron_changed & iv_iron_received] -
        screening_step_hemoglobins[scenario][oral_iron_changed & iv_iron_received],
        iv_iron_effect_hgb,
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: IV iron effect combining with IFA effect (it shouldn't)"

    hemoglobin_after_intervention[scenario] = hemoglobin_after
# Out:
# baseline - Oral iron changes at later ANC:
#       oral_iron_before oral_iron_after
# 7         no_treatment             ifa
# 11        no_treatment             ifa
# 15        no_treatment             ifa
# 20        no_treatment             ifa
# 33        no_treatment             ifa
# ...                ...             ...
# 59934     no_treatment             ifa
# 59941     no_treatment             ifa
# 59953     no_treatment             ifa
# 59988     no_treatment             ifa
# 59993     no_treatment             ifa
#
# [6848 rows x 2 columns]
# anemia_screening_and_iv_iron_scaleup - Oral iron changes at later ANC:
#       oral_iron_before oral_iron_after
# 7         no_treatment             ifa
# 11        no_treatment             ifa
# 15        no_treatment             ifa
# 20        no_treatment             ifa
# 33        no_treatment             ifa
# ...                ...             ...
# 59934     no_treatment             ifa
# ...

# %% [markdown]
# ## Later pregnancy visit timing
#
# After later-pregnancy visit timing timestep:
#
# * CHECK: Anemia person-time stratified by anemia status matches recalculation from post-intervention hemoglobin and ANC visit timing.
# * CHECK: Anemia YLDs stratified by anemia status match recalculation from post-intervention hemoglobin, disability weight, and ANC visit timing.

# %%
later_anc_times = {}

for scenario in scenarios:
    sim = sims[scenario]

    assert sim_step_names[scenario]() == 'later_pregnancy_visit_timing', f"{scenario}: expected later_pregnancy_visit_timing step"
    sim.step()

    pop = sim.get_population(['time_of_later_anc_visit'])

    # CHECK: Anemia person-time
    anemia_status = anemia_status_from_hemoglobin(hemoglobin_after_intervention[scenario])
    later_anc_times[scenario] = (pop.time_of_later_anc_visit / pd.Timedelta(days=365.25)).fillna(12 / 52)
    assert (later_anc_times[scenario] >= first_anc_times[scenario]).all(), f"{scenario}: later ANC visit time earlier than first ANC visit time"
    assert np.allclose(
        (later_anc_times[scenario] - first_anc_times[scenario]).groupby(anemia_status).sum().sort_index(),
        (sim.get_results()['anemia_person_time'].groupby('anemia_status').value.sum() - recorded_anemia_person_time[scenario].groupby('anemia_status').value.sum()).sort_index(),
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: later ANC timestep anemia person-time does not match recalculation"
    recorded_anemia_person_time[scenario] = sim.get_results()['anemia_person_time']

    # CHECK: Anemia YLDs
    dw = anemia_status.map(anemia_status_to_dw).astype(float)
    assert np.allclose(
        (dw * (later_anc_times[scenario] - first_anc_times[scenario])).groupby(anemia_status).sum().sort_index(),
        (sim.get_results()['anemia_ylds'].groupby('anemia_status').value.sum() - recorded_anemia_ylds[scenario].groupby('anemia_status').value.sum()).sort_index(),
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: later ANC timestep anemia YLDs do not match recalculation"
    recorded_anemia_ylds[scenario] = sim.get_results()['anemia_ylds']

# %% [markdown]
# ## Ultrasound
#
# Step all sims to ultrasound, then do cross-scenario comparisons for LBWSG shifts and stillbirth relative risk.
#
# CHECK: The proportion of stillbirths for those receiving IV iron changes between scenarios
# with a curve similar to the one saved in the artifact. Type: manual check.
#
# CHECK: Each of gestational age and birthweight vary between scenarios for the simulants who received IV iron,
# by an amount matching the shift saved in the artifact, *except* for simulants whose birth outcome changed. Type: precise assert.

# %%
# Step all sims to ultrasound
for scenario in scenarios:
    sim = sims[scenario]
    while sim_step_names[scenario]() != "ultrasound":
        sim.step()
    sim.step()  # advance past ultrasound

    # CHECK: Anemia person-time
    anemia_status = anemia_status_from_hemoglobin(hemoglobin_after_intervention[scenario])
    pop = sim.get_population(['pregnancy_outcome'])

    # These pipelines now agree
    gestational_age = sim.get_population("low_birth_weight_and_short_gestation.birth_exposure")["gestational_age"] * 7 / 365.25
    pregnancy_duration = sim.get_population("pregnancy_duration") / pd.Timedelta(days=365.25)
    assert np.allclose(
        gestational_age,
        pregnancy_duration,
        rtol=0,
        atol=1e-7,
    )

    # NOTE: Currently, partial term pregnancies can be assigned a placeholder later ANC time
    # that exceeds their pregnancy duration.
    # Because these pregnancies do not attend later ANC, their hemoglobin does not change over this time and therefore this mathematically works out.
    # However, it is confusing -- we first add *extra* YLDs for these pregnancies here, then delete them with negative duration in the final step.
    assert not (
        pregnancy_duration[pop.pregnancy_outcome == "partial_term"] >= later_anc_times[scenario][pop.pregnancy_outcome == "partial_term"]
    ).all(), f"xfail: {scenario}: later ANC time can exceed pregnancy duration for abortion/miscarriage/ectopic pregnancies"

    # NOTE: There could also theoretically be exceedance due to IV iron, in scenarios that have it --
    # the application of IV iron can reduce gestational age.
    # However we don't see this in the current simulations, likely because the IV iron effect is relatively small
    # and we initialize later ANC times to be at least 2 weeks before the end of pregnancy.
    should_allow_exceedance = pop.pregnancy_outcome.isin(["partial_term"])
    assert (pregnancy_duration[~should_allow_exceedance] >= later_anc_times[scenario][~should_allow_exceedance]).all(), f"{scenario}: later ANC time exceeds pregnancy duration for pregnancies where it should not"

    assert np.allclose(
        (pregnancy_duration - later_anc_times[scenario]).groupby(anemia_status).sum().sort_index(),
        (sim.get_results()['anemia_person_time'].groupby('anemia_status').value.sum() - recorded_anemia_person_time[scenario].groupby('anemia_status').value.sum()).sort_index(),
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: ultrasound timestep anemia person-time does not match recalculation"
    recorded_anemia_person_time[scenario] = sim.get_results()['anemia_person_time']

    # CHECK: Anemia YLDs
    dw = anemia_status.map(anemia_status_to_dw).astype(float)
    assert np.allclose(
        (dw * (pregnancy_duration - later_anc_times[scenario])).groupby(anemia_status).sum().sort_index(),
        (sim.get_results()['anemia_ylds'].groupby('anemia_status').value.sum() - recorded_anemia_ylds[scenario].groupby('anemia_status').value.sum()).sort_index(),
        rtol=0,
        atol=1e-7,
    ), f"{scenario}: ultrasound timestep anemia YLDs do not match recalculation"
    recorded_anemia_ylds[scenario] = sim.get_results()['anemia_ylds']

# %%
# Cross-scenario: LBWSG shifts and stillbirth RR (baseline vs IV iron)
baseline_ultrasound_pop = sims['baseline'].get_population([
    'iv_iron_intervention', 'gestational_age.exposure', 'birth_weight.exposure',
    'pregnancy_outcome', 'sex_of_child',
])
iv_iron_ultrasound_pop = sims['anemia_screening_and_iv_iron_scaleup'].get_population([
    'iv_iron_intervention', 'gestational_age.exposure', 'birth_weight.exposure',
    'pregnancy_outcome', 'sex_of_child',
])

iv_iron_indices = iv_iron_ultrasound_pop[iv_iron_ultrasound_pop.iv_iron_intervention == 'covered'].index

iv_iron_comp = pd.DataFrame({
    'hemoglobin_first_trimester_iv_iron': first_trimester_hemoglobins['anemia_screening_and_iv_iron_scaleup'].loc[iv_iron_indices],
    'hemoglobin_first_trimester_baseline': first_trimester_hemoglobins['baseline'].loc[iv_iron_indices],
    'gestational_age_exposure_iv_iron': iv_iron_ultrasound_pop.loc[iv_iron_indices, 'gestational_age.exposure'],
    'gestational_age_exposure_baseline': baseline_ultrasound_pop.loc[iv_iron_indices, 'gestational_age.exposure'],
    'birth_weight_exposure_iv_iron': iv_iron_ultrasound_pop.loc[iv_iron_indices, 'birth_weight.exposure'],
    'birth_weight_exposure_baseline': baseline_ultrasound_pop.loc[iv_iron_indices, 'birth_weight.exposure'],
    'pregnancy_outcome_iv_iron': iv_iron_ultrasound_pop.loc[iv_iron_indices, 'pregnancy_outcome'],
    'pregnancy_outcome_baseline': baseline_ultrasound_pop.loc[iv_iron_indices, 'pregnancy_outcome'],
    'sex_of_child': baseline_ultrasound_pop.loc[iv_iron_indices, 'sex_of_child'],
})
iv_iron_comp['ga_diff'] = iv_iron_comp.gestational_age_exposure_iv_iron - iv_iron_comp.gestational_age_exposure_baseline
iv_iron_comp['bw_diff'] = iv_iron_comp.birth_weight_exposure_iv_iron - iv_iron_comp.birth_weight_exposure_baseline

# %%
# Build scenario data from existing sims (already stepped past ultrasound above)
def get_ultrasound_data(scenario):
    sim = sims[scenario]
    pop = sim.get_population([
        'gestational_age.exposure', 'birth_weight.exposure', 'hemoglobin.exposure',
        'pregnancy_outcome', 'oral_iron_intervention', 'iv_iron_intervention',
        'sex_of_child', 'anc_attendance',
    ])
    pop['timestep'] = 'ultrasound'
    pop['simulant'] = pop.index.values
    return pop

baseline_data = get_ultrasound_data('baseline')
# mms_data = get_ultrasound_data('mms_total_scaleup') # TODO put this back
iv_iron_data = get_ultrasound_data('anemia_screening_and_iv_iron_scaleup')

# %%
#mms_indices = mms_data.loc[mms_data.oral_iron_intervention == 'mms'].index

# %% [markdown]
# CHECK: Stillbirth rate does not differ between those receiving IFA vs nothing in the baseline scenario.
#
# Type: manual.

# %%
(
    baseline_data[
        (baseline_data.timestep == 'ultrasound') &
        (baseline_data.anc_attendance != 'none')
    ]
        .assign(stillbirth=lambda df: df.pregnancy_outcome == 'stillbirth')
        .groupby(['oral_iron_intervention'])
        .stillbirth.mean()
        .pipe(lambda x: x['ifa'] / x['no_treatment'])
)
# https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id32
# very close to 1
# Out:
# np.float64(1.0053873734537613)

# %% [markdown]
# CHECK: The proportion of stillbirths for those receiving MMS changes between scenarios
# with an RR similar to the one saved in the artifact.
#
# Type: fuzzy check of proportion.

# %%
cols = ['gestational_age.exposure','birth_weight.exposure','hemoglobin.exposure','pregnancy_outcome',
       'oral_iron_intervention','iv_iron_intervention','timestep','sex_of_child','simulant']

# %%
#mms_comp = mms_data.loc[mms_indices][cols].merge(baseline_data.loc[mms_indices][cols],
#                                                                on=['simulant','timestep'], suffixes=['_mms','_baseline']).drop_duplicates()

# %%
#mms_stillbirth_rr

# %%
"""mms_comp.loc[(mms_comp.timestep=='ultrasound')].assign(
    sb_baseline=lambda df: df.pregnancy_outcome_baseline == 'stillbirth', 
    sb_mms=lambda df: df.pregnancy_outcome_mms == 'stillbirth',
)[['sb_baseline', 'sb_mms']].sum().pipe(lambda x: x['sb_mms'] / x['sb_baseline'])"""
# looks reasonable
# Out:
# "mms_comp.loc[(mms_comp.timestep=='ultrasound')].assign(\n    sb_baseline=lambda df: df.pregnancy_outcome_baseline == 'stillbirth', \n    sb_mms=lambda df: df.pregnancy_outcome_mms == 'stillbirth',\n)[['sb_baseline', 'sb_mms']].sum().pipe(lambda x: x['sb_mms'] / x['sb_baseline'])"

# %%
# Stillbirth RR plot
def plot_sb_rr():
    plot_data = pd.DataFrame()
    plot_data['pre_int_hgb'] = iv_iron_comp['hemoglobin_first_trimester_iv_iron'].values
    plot_data['iv_iron_outcome'] = iv_iron_comp['pregnancy_outcome_iv_iron'].values
    plot_data['baseline_outcome'] = iv_iron_comp['pregnancy_outcome_baseline'].values
    plot_data['hemoglobin_bin'] = pd.cut(plot_data.pre_int_hgb, 15)
    baseline_sb = plot_data.rename(columns={'baseline_outcome':'outcome'}).groupby('hemoglobin_bin').outcome.value_counts(normalize=True)
    intervention_sb = plot_data.rename(columns={'iv_iron_outcome':'outcome'}).groupby('hemoglobin_bin').outcome.value_counts(normalize=True)
    sb_rr = (intervention_sb / baseline_sb).reset_index()
    sb_rr = sb_rr.loc[sb_rr.outcome=='stillbirth']
    sb_rr['hgb_bin_start'] = [sb_rr.loc[i].hemoglobin_bin.left for i in sb_rr.index]
    sb_rr['hgb_bin_end'] = [sb_rr.loc[i].hemoglobin_bin.right for i in sb_rr.index]
    sb_rr['hgb_bin_mid'] = (sb_rr.hgb_bin_end - sb_rr.hgb_bin_start) / 2 + sb_rr.hgb_bin_start
    plt.figure()
    plt.plot(sb_rr.hgb_bin_mid, sb_rr['proportion'], label='Simulation', marker='o')
    plt.plot(art_iv_iron_sb_rr.reset_index().first_trimester_hemoglobin_exposure_start, art_iv_iron_sb_rr, color='tab:orange', label='Artifact')
    plt.xlabel('First trimester ANC hemoglobin')
    plt.ylabel('RR of stillbirth due to IV iron')
    plt.title('Effect of IV iron on stillbirth by first_trimester_anc hemoglobin exposure')
    plt.grid()
    plt.legend()

plot_sb_rr()

# %% [markdown]
# CHECK: Gestational age for live births varies within the baseline scenario between simulants who received IFA and no oral iron,
# conditional on ANC attendance,
# by amounts approximately matching the shift saved in the artifact.
#
# Type: manual.

# %%
ifa_ga_shift
# Out:
# np.float64(0.1389184515617163)

# %%
(
    baseline_data[
        (baseline_data.timestep == 'ultrasound') &
        (baseline_data.anc_attendance != 'none') &
        (baseline_data.pregnancy_outcome == 'live_birth')
    ]
        .groupby(['oral_iron_intervention', 'anc_attendance'])
        ['gestational_age.exposure']
        .mean()
        .pipe(lambda x: x['ifa'] - x['no_treatment'])
)
# Looks to approximately match target
# Out:
# anc_attendance
# first_trimester_and_later_pregnancy    0.168858
# later_pregnancy_only                   0.145414
# Name: gestational_age.exposure, dtype: float64

# %% [markdown]
# CHECK: Preterm birth for live births varies within the baseline scenario between simulants who received IFA and no oral iron,
# conditional on ANC attendance,
# by a ratio approximately matching the RR in the docs (not saved at the draw level)
#
# Type: manual.

# %%
(
    baseline_data[
        (baseline_data.timestep == 'ultrasound') &
        (baseline_data.anc_attendance != 'none') &
        (baseline_data.pregnancy_outcome == 'live_birth')
    ]
        .assign(preterm=lambda c: c['gestational_age.exposure'] < 37)
        .groupby(['oral_iron_intervention'])
        .preterm
        .mean()
        .pipe(lambda x: x['ifa'] / x['no_treatment'])
)
# https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28
# 0.9 (95% CI: 0.86, 0.95)
# seems reasonable
# Out:
# np.float64(0.8751436727292305)

# %% [markdown]
# CHECK: Gestational age varies between scenarios for the simulants who received MMS rather than IFA,
# by amounts matching the shifts saved in the artifact, *except* for simulants whose birth outcome changed.
#
# Type: precise assert.

# %%
"""mms_comp['ga_diff'] = mms_comp['gestational_age.exposure_mms'] - mms_comp['gestational_age.exposure_baseline']
mms_comp['bw_diff'] = mms_comp['birth_weight.exposure_mms'] - mms_comp['birth_weight.exposure_baseline']"""
# Out:
# "mms_comp['ga_diff'] = mms_comp['gestational_age.exposure_mms'] - mms_comp['gestational_age.exposure_baseline']\nmms_comp['bw_diff'] = mms_comp['birth_weight.exposure_mms'] - mms_comp['birth_weight.exposure_baseline']"

# %%
"""is_live_birth = (
    (mms_comp.pregnancy_outcome_baseline == 'live_birth') &
    (mms_comp.pregnancy_outcome_mms == 'live_birth')
)

mms_ga_comp = mms_comp[
    (mms_comp.timestep == 'ultrasound') &
    is_live_birth &
    # NOTE: MMS effects relative to IFA https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28
    # We can't easily test the effects for those who went from no oral iron to MMS,
    # because that is a 2 step process where the second step depends on the intermediate GA which is not saved
    (mms_comp.oral_iron_intervention_baseline == 'ifa')
].assign(
    very_preterm_baseline=lambda c: c['gestational_age.exposure_baseline'] < 32 - (mms_ga_shift.loc[False] - mms_ga_shift.loc[True])
)
# Modulo floating point imprecision, this determines the value
assert (mms_ga_comp.assign(ga_diff=lambda c: c.ga_diff.round(7)).groupby('very_preterm_baseline').ga_diff.nunique() == 1).all()

mms_ga_comp = mms_ga_comp.groupby('very_preterm_baseline').ga_diff.first()
assert np.allclose(mms_ga_comp, mms_ga_shift, rtol=0, atol=1e-7)
mms_ga_comp"""
# Out:
# "is_live_birth = (\n    (mms_comp.pregnancy_outcome_baseline == 'live_birth') &\n    (mms_comp.pregnancy_outcome_mms == 'live_birth')\n)\n\nmms_ga_comp = mms_comp[\n    (mms_comp.timestep == 'ultrasound') &\n    is_live_birth &\n    # NOTE: MMS effects relative to IFA https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28\n    # We can't easily test the effects for those who went from no oral iron to MMS,\n    # because that is a 2 step process where the second step depends on the intermediate GA which is not saved\n    (mms_comp.oral_iron_intervention_baseline == 'ifa')\n].assign(\n    very_preterm_baseline=lambda c: c['gestational_age.exposure_baseline'] < 32 - (mms_ga_shift.loc[False] - mms_ga_shift.loc[True])\n)\n# Modulo floating point imprecision, this determines the value\nassert (mms_ga_comp.assign(ga_diff=lambda c: c.ga_diff.round(7)).groupby('very_preterm_baseline').ga_diff.nunique() ==
# ...

# %% [markdown]
# CHECK: Preterm birth for live births varies between scenarios for the simulants who received MMS rather than IFA,
# by a ratio approximately matching the RR in the docs (not saved at the draw level).
#
# Type: fuzzy check of proportion.

# %%
"""mms_comp[
    (mms_comp.timestep == 'ultrasound') &
    is_live_birth &
    # NOTE: MMS effects relative to IFA https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28
    # We can't easily test the effects for those who went from no oral iron to MMS,
    # because that is a 2 step process where the second step depends on the intermediate GA which is not saved
    (mms_comp.oral_iron_intervention_baseline == 'ifa') &
    (mms_comp['gestational_age.exposure_baseline'] < 37)
].assign(
    preterm=lambda c: (c['gestational_age.exposure_mms'] < 37)
).preterm.mean()
# https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28
# 0.91 (95% CI: 0.84, 0.99)
# seems reasonable"""
# Out:
# "mms_comp[\n    (mms_comp.timestep == 'ultrasound') &\n    is_live_birth &\n    # NOTE: MMS effects relative to IFA https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28\n    # We can't easily test the effects for those who went from no oral iron to MMS,\n    # because that is a 2 step process where the second step depends on the intermediate GA which is not saved\n    (mms_comp.oral_iron_intervention_baseline == 'ifa') &\n    (mms_comp['gestational_age.exposure_baseline'] < 37)\n].assign(\n    preterm=lambda c: (c['gestational_age.exposure_mms'] < 37)\n).preterm.mean()\n# https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28\n# 0.91 (95% CI: 0.84, 0.99)\n# seems reasonable"

# %% [markdown]
# CHECK: Very preterm birth for live births varies between scenarios for the simulants who received MMS rather than IFA,
# by a ratio approximately matching the RR in the docs (not saved at the draw level).
#
# Type: fuzzy check of proportion.

# %%
"""mms_comp[
    (mms_comp.timestep == 'ultrasound') &
    is_live_birth &
    # NOTE: MMS effects relative to IFA https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28
    # We can't easily test the effects for those who went from no oral iron to MMS,
    # because that is a 2 step process where the second step depends on the intermediate GA which is not saved
    (mms_comp.oral_iron_intervention_baseline == 'ifa') &
    (mms_comp['gestational_age.exposure_baseline'] < 32)
].assign(
    very_preterm=lambda c: (c['gestational_age.exposure_mms'] < 32)
).very_preterm.mean()
# https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28
# 0.81 (95% CI: 0.71, 0.93)
# seems reasonable"""
# Out:
# "mms_comp[\n    (mms_comp.timestep == 'ultrasound') &\n    is_live_birth &\n    # NOTE: MMS effects relative to IFA https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28\n    # We can't easily test the effects for those who went from no oral iron to MMS,\n    # because that is a 2 step process where the second step depends on the intermediate GA which is not saved\n    (mms_comp.oral_iron_intervention_baseline == 'ifa') &\n    (mms_comp['gestational_age.exposure_baseline'] < 32)\n].assign(\n    very_preterm=lambda c: (c['gestational_age.exposure_mms'] < 32)\n).very_preterm.mean()\n# https://vivarium-research.readthedocs.io/en/latest/models/intervention_models/mncnh_pregnancy/oral_iron_antenatal/oral_iron_antenatal.html#id28\n# 0.81 (95% CI: 0.71, 0.93)\n# seems reasonable"

# %% [markdown]
# TODO: Check birthweight shifts

# %% [markdown]
# CHECK: Each of gestational age and birthweight vary between scenarios for the simulants who received IV iron,
# by an amount matching the shift saved in the artifact, *except* for simulants whose birth outcome changed.
#
# Type: precise assert.

# %%
def plot_iv_iron_lbwsg_shifts(outcome, sexes=('Male', 'Female'), hgb_exposure_timing='first_trimester_anc', consistent_live_birth_restriction=False):
    outcome_col = {
        'birth_weight': 'bw_diff',
        'gestational_age': 'ga_diff',
    }[outcome]

    for sex in sexes:
        plt.figure()

        is_live_birth = (
            (iv_iron_comp.pregnancy_outcome_baseline == 'live_birth') &
            (iv_iron_comp.pregnancy_outcome_iv_iron == 'live_birth')
        )

        live_birth_simulants = iv_iron_comp.loc[is_live_birth].index

        p = iv_iron_comp.loc[iv_iron_comp.sex_of_child == sex]
        a = art_iv_iron_lbwsg_shifts.loc[sex, outcome]

        if consistent_live_birth_restriction:
            p = p.loc[p.index.isin(live_birth_simulants)]

            starts = a.index.get_level_values('first_trimester_hemoglobin_exposure_start')
            ends = a.index.get_level_values('first_trimester_hemoglobin_exposure_end')

            starts = starts.to_series().replace(starts.min(), -np.inf)

            intervals = pd.IntervalIndex.from_arrays(starts, ends, closed="left")

            hgb_values = p['hemoglobin_first_trimester_iv_iron']
            idx = intervals.get_indexer(hgb_values)

            recalc = pd.Series(a.to_numpy()[idx], index=p.index)

            assert np.allclose(
                recalc,
                p[outcome_col],
                rtol=0,
                atol=1e-10,
            ), f"{outcome} shift doesn't match recalculation"

        x = p['hemoglobin_first_trimester_iv_iron']
        y = p[outcome_col]

        plt.scatter(x, y, label='Simulation')
        plt.plot(
            a.reset_index().first_trimester_hemoglobin_exposure_start,
            a,
            color='tab:orange',
            label='Artifact',
        )

        plt.xlabel('Hemoglobin exposure')
        plt.ylabel(f'{outcome} shift')
        plt.title(f'IV iron effect on {outcome} based on first_trimester_anc hemoglobin exposure')
        plt.grid()
        plt.legend()

# %%
plot_iv_iron_lbwsg_shifts(outcome='gestational_age')
plot_iv_iron_lbwsg_shifts(outcome='birth_weight')

# %%
plot_iv_iron_lbwsg_shifts(outcome='gestational_age', consistent_live_birth_restriction=True)
plot_iv_iron_lbwsg_shifts(outcome='birth_weight', consistent_live_birth_restriction=True)

# %%
for scenario in scenarios:
    if scenario != 'anemia_screening_and_iv_iron_scaleup' and 'OralIronEffectOnHemoglobin()' not in included_components:
        assert np.allclose(
            raw_hemoglobins[scenario],
            hemoglobin_after_intervention[scenario],
            rtol=0,
            atol=1e-7,
        ), f"{scenario}: Hemoglobin changed without oral iron effect included in model"

# %% [markdown]
# ## Maternal outcomes (hemorrhage and sepsis)
#
# For each outcome (maternal hemorrhage and maternal sepsis) timestep:
#
# * CHECK: Hemoglobin unchanged from after later-pregnancy intervention timestep.
# * CHECK: Simulant-level relative risk on this outcome equals a recalculated interpolation of the artifact RRs.
# * CHECK: The relative risk of the event happening in each quantile-bin of hemoglobin (vs the quantile-bin that contains the TMREL) approximately matches the mean of the artifact RRs for hemoglobin values in that quantile-bin. Type: manual, since this is a pretty odd check with lots of room for imprecision. We should consider if there is another good way for us to (partially) check this.

# %%
outcome = "postpartum_depression"
sim.get_population([outcome])
sim.get_population(f'hemoglobin_on_{outcome}.incidence_risk.relative_risk')
outcome_art_rrs = art_rrs.loc[outcome]

# %%
outcomes = ['antepartum_hemorrhage', 'postpartum_hemorrhage', 'maternal_sepsis_and_other_maternal_infections']

# APH and PPH share the same RR data keyed as "maternal_hemorrhage" in the artifact
OUTCOME_TO_ART_ENTITY = {
    'antepartum_hemorrhage': 'maternal_hemorrhage',
    'postpartum_hemorrhage': 'maternal_hemorrhage',
    'maternal_sepsis_and_other_maternal_infections': 'maternal_sepsis_and_other_maternal_infections',
    'postpartum_depression': 'postpartum_depression',
}

def plot_outcome_incidence_effects(outcome):
    hemoglobin_exposure = sim.get_population('hemoglobin.exposure')
    assert (
        hemoglobin_exposure == hemoglobin_after_intervention[scenario]
    ).all(), f"{scenario}: Changes to hemoglobin after late-pregnancy ANC"
    stepped_pop = pd.concat([
        sim.get_population([outcome]),
        raw_hemoglobins[scenario],
        initial_hemoglobins[scenario],
        hemoglobin_exposure.rename('hemoglobin_exposure'),
        sim.get_population(f'hemoglobin_on_{outcome}.incidence_risk.relative_risk')
    ], axis=1)

    art_entity = OUTCOME_TO_ART_ENTITY[outcome]
    outcome_art_rrs = art_rrs.loc[art_entity]
    assert np.allclose(
        np.interp(stepped_pop['hemoglobin_exposure'], outcome_art_rrs.index, outcome_art_rrs),
        stepped_pop[f'hemoglobin_on_{outcome}.incidence_risk.relative_risk'],
        rtol=0,
        atol=1e-2,
    ), f"{scenario}: {outcome} relative risk doesn't match recalculation"

    # NOTE: This plot is redundant to the check above
    plt.scatter(stepped_pop['raw_hemoglobin'], stepped_pop[f'hemoglobin_on_{outcome}.incidence_risk.relative_risk'], s=20, label='raw hemoglobin exposure')
    plt.scatter(stepped_pop['hemoglobin_exposure'], stepped_pop[f'hemoglobin_on_{outcome}.incidence_risk.relative_risk'], s=20, label='intervention-modified hemoglobin exposure')
    plt.plot(outcome_art_rrs.index, outcome_art_rrs, label='artifact RR curve', color='tab:green')
    plt.legend()
    plt.xlabel('hemoglobin exposure (g/L)')
    plt.ylabel(f'relative risk of {outcome}')
    plt.title(f'{scenario}: Which hemoglobin exposure measure is affecting RR?')
    plt.show()

    # Check if this actually translates to incidence
    stepped_pop['hb_bin'] = pd.qcut(stepped_pop['hemoglobin_exposure'], 30)
    sim_rate = stepped_pop.groupby('hb_bin')[outcome].value_counts(normalize=True).unstack().fillna(0)

    tmrel_bin = [b for b in sim_rate.index if b.left <= tmrel < b.right][0]
    tmrel_rate = sim_rate.loc[tmrel_bin]

    art_rrs_by_bin = art_rrs.reset_index().assign(hb_bin=lambda df: pd.cut(df.parameter, stepped_pop['hb_bin'].cat.categories)).groupby('hb_bin')[draw].mean()
    art_rrs_by_bin.plot(kind='line', color='tab:orange', label='Artifact')

    plt.xlabel('Hemoglobin Exposure (binned)')
    plt.ylabel('Relative Rate vs. Bin Containing 120 g/L')
    plt.title(f'{scenario}: Relative Rate of {outcome} by Hemoglobin Exposure')
    (sim_rate[True] / tmrel_rate[True]).plot(kind='bar')
    plt.legend()
    plt.xticks(rotation=90)
    plt.grid()
    plt.show()

# %%
birth_hgb = {}
for outcome in outcomes:
    # Step all sims to this outcome
    for scenario in scenarios:
        sim = sims[scenario]
        while sim_step_names[scenario]() != outcome:
            sim.step()
        if sim._clock.step_name == 'postpartum_hemorrhage':
            birth_hgb[scenario] = sim.get_population('hemoglobin_exposure_for_non_loglinear_riskeffect') # hgb value from before postpartum_hemorrage step
        sim.step()  # advance past outcome
        plot_outcome_incidence_effects(outcome)

# %% [markdown]
# ## Early neonatal mortality and final YLD checks

# %% [markdown]
# CHECK: Hemoglobin changes correctly across each of the two postpartum steps.
#
# * At early_postpartum (0-6w), hemoglobin is the pregnancy value carried in from later-pregnancy intervention plus the 0-6w APH/PPH and maternal-sepsis shifts, clipped at 0. Iron interventions are still in force here.
# * At late_postpartum (6w-9m), hemoglobin is a fresh draw from the non-pregnant distribution plus the 6w-9m APH/PPH and maternal-sepsis shifts, clipped at 0. The pregnancy value is discarded wholesale, so this contains no baseline IFA deletion term and no oral/IV iron effect -- re-adding either one breaks the match.
# * Since main was merged in, partial-term APH pregnancies no longer exist -- AntepartumHemorrhage assigns APH to stillbirths and live births only -- so the model38.3 carve-out that excluded them from this check is gone and the whole population is compared. At late_postpartum every living simulant is redrawn: nobody is still pregnant by 6w-9m. Simulants who died are not redrawn, and with iron gated off at that step they sit at exactly their initial (IFA-deleted) pregnancy hemoglobin. PPH is only ever assigned to full-term births as always.
#
# Type: precise assert.

# %%
# Hemorrhage hemoglobin shifts, by postpartum period. Single-value keys with no
# demographic variation.
pph_shift_0_6w = art.load('risk_effect.hemorrhage_hemoglobin_shift.pph_shift_0_6w')[draw].item()
aph_shift_0_6w = art.load('risk_effect.hemorrhage_hemoglobin_shift.aph_shift_0_6w')[draw].item()
pph_shift_6w_9m = art.load('risk_effect.hemorrhage_hemoglobin_shift.pph_shift_6w_9m')[draw].item()
aph_shift_6w_9m = art.load('risk_effect.hemorrhage_hemoglobin_shift.aph_shift_6w_9m')[draw].item()

# Maternal sepsis shifts the same two postpartum periods (SepsisEffectsOnHemoglobin,
# arrived with the main merge). Indexed by postpartum_period, one column per draw.
_sepsis_shift = art.load(
    'cause.maternal_sepsis_and_other_maternal_infections.hemoglobin_shift'
)[draw]
sepsis_shift_0_6w = _sepsis_shift.loc['early_postpartum'].item()
sepsis_shift_6w_9m = _sepsis_shift.loc['late_postpartum'].item()

POSTPARTUM_SHIFTS = {
    # step_name: (pph shift, aph shift, sepsis shift)
    'early_postpartum': (pph_shift_0_6w, aph_shift_0_6w, sepsis_shift_0_6w),
    'late_postpartum': (pph_shift_6w_9m, aph_shift_6w_9m, sepsis_shift_6w_9m),
}

# The baseline IFA deletion subtracted from hemoglobin at the start of pregnancy.
ifa_deletion = ifa_coverage * ifa_effect_hgb

pd.Series({
    'pph_shift_0_6w': pph_shift_0_6w,
    'aph_shift_0_6w': aph_shift_0_6w,
    'pph_shift_6w_9m': pph_shift_6w_9m,
    'aph_shift_6w_9m': aph_shift_6w_9m,
    'sepsis_shift_0_6w': sepsis_shift_0_6w,
    'sepsis_shift_6w_9m': sepsis_shift_6w_9m,
    'ifa_deletion': ifa_deletion,
    'ifa_effect_hgb': ifa_effect_hgb,
    'iv_iron_effect_hgb': iv_iron_effect_hgb,
})
# Out:
# pph_shift_0_6w       -18.273376
# aph_shift_0_6w       -18.273376
# pph_shift_6w_9m       -5.455156
# aph_shift_6w_9m       -5.455156
# sepsis_shift_0_6w    -13.247920
# sepsis_shift_6w_9m    -3.042343
# ifa_deletion           4.578792
# ifa_effect_hgb         9.922281
# iv_iron_effect_hgb    21.659714
# dtype: float64

# %%
final_pops = {}

# Postpartum anemia person-time and YLDs are accrued over two explicit postpartum
# periods (replacing the old early_neonatal_mortality / postpartum_hemoglobin_nine_month
# accrual steps, which now sit *after* these periods and no longer accrue anemia time):
#   early_postpartum (0-6 weeks):  duration 6 weeks,  pregnancy anemia thresholds
#   late_postpartum  (6-39 weeks): duration 33 weeks, non-pregnancy anemia thresholds
# The AnemiaYLDsObserver samples on time_step__prepare (pop_filter "is_alive == True"),
# so we read hemoglobin and is_alive at each step *before* sim.step(). The postpartum
# hemorrhage shift / non-pregnant redraw is a value-pipeline modifier gated on the
# simulation event name, so it is already live in hemoglobin.exposure once
# _sim_step_name() returns this step -- i.e. the value read below is exactly the one the
# observer sees. Hemoglobin.on_time_step only snapshots it into the hemoglobin_exposure
# column; it does not apply the shift.
# Use the same constants the AnemiaYLDsObserver uses so the recalculation matches exactly.
from vivarium_gates_mncnh.constants.data_values import (
    ANEMIA_THRESHOLDS_NON_PREGNANCY,
    DAYS_PER_YEAR,
    EARLY_POSTPARTUM_END_DAYS,
    LATE_POSTPARTUM_END_DAYS,
    PREGNANCY_OUTCOMES,
)

POSTPARTUM_STEPS = [
    # (step_name, duration_years, anemia thresholds -- None => pregnancy thresholds)
    ("early_postpartum", EARLY_POSTPARTUM_END_DAYS / DAYS_PER_YEAR, None),
    (
        "late_postpartum",
        (LATE_POSTPARTUM_END_DAYS - EARLY_POSTPARTUM_END_DAYS) / DAYS_PER_YEAR,
        ANEMIA_THRESHOLDS_NON_PREGNANCY,
    ),
]

for scenario in scenarios:
    sim = sims[scenario]

    assert (
        sim.get_population('hemoglobin.exposure') == hemoglobin_after_intervention[scenario]
    ).all(), f"{scenario}: Changes to hemoglobin after late-pregnancy ANC"

    for step_name, duration, thresholds in POSTPARTUM_STEPS:
        while sim_step_names[scenario]() != step_name:
            sim.step()

        # Read hemoglobin + is_alive for this step (the prepare-phase view the observer
        # uses); the shift for this postpartum period is already applied, see above.
        step_hemoglobin = sim.get_population('hemoglobin.exposure')
        parent_survived_birth = sim.get_population('is_alive')
        anemia_status = anemia_status_from_hemoglobin(step_hemoglobin, thresholds)
        dw = anemia_status.map(anemia_status_to_dw).astype(float)

        # CHECK: hemoglobin changed correctly at this postpartum step.
        pp_pop = sim.get_population([
            'pregnancy_outcome', 'antepartum_hemorrhage', 'postpartum_hemorrhage',
            'maternal_sepsis_and_other_maternal_infections',
        ])
        pph = pp_pop.postpartum_hemorrhage.fillna(False).astype(bool)
        aph = pp_pop.antepartum_hemorrhage.fillna(False).astype(bool)
        sepsis = pp_pop.maternal_sepsis_and_other_maternal_infections.fillna(False).astype(bool)
        pph_shift, aph_shift, sepsis_shift = POSTPARTUM_SHIFTS[step_name]
        # NOTE: the sepsis shift is reconstructed *inside* the clip, alongside the
        # hemorrhage shifts. SepsisEffectsOnHemoglobin is a separate attribute modifier,
        # so if it in fact runs after the postpartum modifier it lands outside the clip
        # instead -- the same subtlety the iron effect has at 0-6w below. Only simulants
        # the clip binds on can tell the two apart; if this check fails on sepsis cases,
        # move the term out of the clip. Unverified: needs an interactive run.

        if step_name == 'early_postpartum':
            # 0-6w: mirror the hemoglobin.exposure mutator chain, which applies the
            # hemorrhage shifts and clips at 0 in the postpartum modifier, then the iron
            # modifiers, then the sepsis shift last -- with a final floor at 0. Both the
            # iron effect and the sepsis shift therefore land OUTSIDE the hemorrhage clip
            # and have to be split back out here.
            iron_effect = (
                hemoglobin_after_intervention[scenario] - initial_hemoglobins[scenario]
            )
            shifted = (
                initial_hemoglobins[scenario]
                + pph * pph_shift
                + aph * aph_shift
            ).clip(lower=0)
            expected = (shifted + iron_effect + sepsis * sepsis_shift).clip(lower=0)

        else:
            # 6w-9m: the pregnancy value is discarded and replaced by a fresh draw from the
            # non-pregnant distribution, with the iron modifiers gated off. Nothing is added
            # after the clip here, so no such split is needed.
            non_pregnant = sim.get_population('non_pregnant_hemoglobin.exposure')
            shifted = (
                non_pregnant + pph * pph_shift + aph * aph_shift
            ).clip(lower=0)
            shifted = (shifted + sepsis * sepsis_shift).clip(lower=0)
            # Every living simulant is redrawn here, partial-term pregnancies included --
            # nobody is still pregnant by 6w-9m.
            expected = shifted
            # Simulants who died are not redrawn and take no hemorrhage shift, so with iron
            # gated off they sit at their initial (IFA-deleted) pregnancy hemoglobin -- but
            # the sepsis modifier is NOT gated on survival, so it still lands on them.
            # NOTE: currently this check includes pregnancies where is-alive is not true.
            # If these pregnancies receiving APH/PPH or sepsis hgb shifts is not the correct
            # behavior, we should change the check to fail if they receive shifts.
            expected[~parent_survived_birth] = (
                (initial_hemoglobins[scenario] + sepsis * sepsis_shift).clip(lower=0)
            )[~parent_survived_birth]

        # The model38.3 carve-out for partial-term APH pregnancies is gone: merged
        # AntepartumHemorrhage assigns APH to stillbirths and live births only, so no
        # partial-term simulant carries APH and the whole population is checked again.
        assert not (
            aph & (pp_pop.pregnancy_outcome == PREGNANCY_OUTCOMES.PARTIAL_TERM_OUTCOME)
        ).any(), f"{scenario}: partial-term pregnancy assigned antepartum hemorrhage"

        assert np.allclose(step_hemoglobin, expected, rtol=0, atol=1e-7), (
            f"{scenario}: {step_name} hemoglobin does not match recalculation "
            f"(max abs err {np.abs(step_hemoglobin - expected).max():.3e})"
        )

        sim.step()  # advance past this postpartum step

        # CHECK: Anemia person-time (only simulants alive at the step contribute)
        assert np.allclose(
            pd.Series(duration, index=anemia_status[parent_survived_birth].index).groupby(anemia_status[parent_survived_birth]).sum().sort_index(),
            (sim.get_results()['anemia_person_time'].groupby('anemia_status').value.sum() - recorded_anemia_person_time[scenario].groupby('anemia_status').value.sum()).sort_index(),
            rtol=0,
            atol=1e-7,
        ), f"{scenario}: {step_name} anemia person-time does not match recalculation"
        recorded_anemia_person_time[scenario] = sim.get_results()['anemia_person_time']

        # CHECK: Anemia YLDs
        assert np.allclose(
            (dw[parent_survived_birth] * duration).groupby(anemia_status[parent_survived_birth]).sum().sort_index(),
            (sim.get_results()['anemia_ylds'].groupby('anemia_status').value.sum() - recorded_anemia_ylds[scenario].groupby('anemia_status').value.sum()).sort_index(),
            rtol=0,
            atol=1e-7,
        ), f"{scenario}: {step_name} anemia YLDs do not match recalculation"
        recorded_anemia_ylds[scenario] = sim.get_results()['anemia_ylds']

    final_pop = sim.get_population([
        'anc_attendance', 'oral_iron_intervention',
        'antepartum_hemorrhage', 'postpartum_hemorrhage',
    ])
    final_pop = pd.concat([
        final_pop,
        raw_hemoglobins[scenario],
        initial_hemoglobins[scenario],
        # Intervention-modified hemoglobin (reflects oral/IV iron; pre postpartum
        # hemorrhage shift) -- this is what the oral-iron / hemorrhage-RR checks below expect.
        hemoglobin_after_intervention[scenario].rename('hemoglobin_exposure'),
    ], axis=1)
    final_pops[scenario] = final_pop

print("All final YLD checks passed.")
# Out:
# All final YLD checks passed.

# %%
sim.get_results()['anemia_person_time'].groupby('anemia_status').value.sum()
# Out:
# anemia_status
# severe         1800.064044
# moderate      12007.949544
# mild          10241.854784
# not_anemic    53009.889012
# Name: value, dtype: float64

# %%
# Diagnostic: late-postpartum (6w-9m) anemia person-time recalculation, grouped by the
# non-pregnancy-threshold anemia status left in scope after the loop above.
pd.Series((39 - 6) * 7 * (1 / 365.25), index=anemia_status[parent_survived_birth].index).groupby(anemia_status[parent_survived_birth]).sum().sort_index()
# Out:
# hemoglobin.exposure
# severe          911.983573
# moderate       6206.168378
# mild           4955.827515
# not_anemic    25815.712526
# dtype: float64

# %% [markdown]
# ## Cross-scenario: MMS vs baseline
#
# * CHECK: The same simulants attend ANC (in each ANC attendance category) in the baseline as in the MMS scale-up scenarios.
# * CHECK: Simulants whose iron interventions did not change between scenarios, have the same final hemoglobin in the scenarios.
# * CHECK: Simulants who changed from IFA in baseline to MMS in the MMS scale-up scenario have the same final hemoglobin.
# * CHECK: Simulants who changed from no oral iron in baseline to MMS in the MMS scale-up scenario have higher hemoglobin in the MMS scenario by the effect of IFA on hemoglobin.

# %%
"""compare_population = final_pops['mms_total_scaleup'].join(
    final_pops['baseline'],
    lsuffix='_mms_total_scaleup',
    rsuffix='_baseline',
)

compare_population['hemoglobin_diff'] = (
    compare_population['hemoglobin_exposure_mms_total_scaleup'] -
    compare_population['hemoglobin_exposure_baseline']
)

assert (
    compare_population.anc_attendance_baseline
    ==
    compare_population.anc_attendance_mms_total_scaleup
).all(), "MMS scale up changing ANC attendance"

assert (
    compare_population[
        (compare_population.oral_iron_intervention_baseline == compare_population.oral_iron_intervention_mms_total_scaleup)
    ].hemoglobin_diff == 0
).all(), "Scenario differences where oral iron didn't change"
if 'OralIronEffectOnHemoglobin()' in included_components:
    assert np.allclose(
        compare_population[
            (compare_population.oral_iron_intervention_baseline == 'no_treatment') &
            (compare_population.oral_iron_intervention_mms_total_scaleup == 'mms')
        ].hemoglobin_diff,
        ifa_effect_hgb
    ), "IFA effect on hemoglobin different from expectation"

    assert (
        compare_population[
            (compare_population.oral_iron_intervention_baseline == 'ifa') &
            (compare_population.oral_iron_intervention_mms_total_scaleup == 'mms')
        ].hemoglobin_diff == 0
    ).all(), "IFA effect on hemoglobin different from MMS effect"

    assert np.allclose(
        compare_population[
            (compare_population.oral_iron_intervention_baseline == 'no_treatment') &
            (compare_population.oral_iron_intervention_mms_total_scaleup == 'mms')
        ].hemoglobin_diff,
        ifa_effect_hgb
    ), "MMS effect on hemoglobin different from expectation"
else:
    assert (
        compare_population[
            (compare_population.oral_iron_intervention_baseline == 'no_treatment') &
            (compare_population.oral_iron_intervention_mms_total_scaleup == 'mms')
        ].hemoglobin_diff == 0
    ).all(), "MMS effect on hemoglobin when OralIronEffectOnHemoglobin not included"

compare_population.groupby('oral_iron_intervention_baseline')['hemoglobin_diff'].describe()"""
# Out:
# 'compare_population = final_pops[\'mms_total_scaleup\'].join(\n    final_pops[\'baseline\'],\n    lsuffix=\'_mms_total_scaleup\',\n    rsuffix=\'_baseline\',\n)\n\ncompare_population[\'hemoglobin_diff\'] = (\n    compare_population[\'hemoglobin_exposure_mms_total_scaleup\'] -\n    compare_population[\'hemoglobin_exposure_baseline\']\n)\n\nassert (\n    compare_population.anc_attendance_baseline\n    ==\n    compare_population.anc_attendance_mms_total_scaleup\n).all(), "MMS scale up changing ANC attendance"\n\nassert (\n    compare_population[\n        (compare_population.oral_iron_intervention_baseline == compare_population.oral_iron_intervention_mms_total_scaleup)\n    ].hemoglobin_diff == 0\n).all(), "Scenario differences where oral iron didn\'t change"\nif \'OralIronEffectOnHemoglobin()\' in included_components:\n    assert np.allclose(\n        compare_population[\n            (compare_population.oral_iron_intervention_baseline == \'no_treatment\') &\n            (compare_populat
# ...

# %%
"""assert (
    compare_population[
        (compare_population.antepartum_hemorrhage_mms_total_scaleup | compare_population.postpartum_hemorrhage_mms_total_scaleup) &
        # NOTE: there is a slight increase in the hemoglobin->hemorrhage effect after 140!
        # https://vivarium-research.readthedocs.io/en/latest/models/risk_effects/hemoglobin/index.html#hemoglobin-effects
        (compare_population.hemoglobin_exposure_mms_total_scaleup < 140)
    ].apply(
        lambda row: row['antepartum_hemorrhage_baseline'] or row['postpartum_hemorrhage_baseline'],
        axis=1,
    ).all()
), "MMS scale up introducing unexpected maternal hemorrhages"
""" # TODO put back this and above cell
# Out:
# 'assert (\n    compare_population[\n        (compare_population.antepartum_hemorrhage_mms_total_scaleup | compare_population.postpartum_hemorrhage_mms_total_scaleup) &\n        # NOTE: there is a slight increase in the hemoglobin->hemorrhage effect after 140!\n        # https://vivarium-research.readthedocs.io/en/latest/models/risk_effects/hemoglobin/index.html#hemoglobin-effects\n        (compare_population.hemoglobin_exposure_mms_total_scaleup < 140)\n    ].apply(\n        lambda row: row[\'antepartum_hemorrhage_baseline\'] or row[\'postpartum_hemorrhage_baseline\'],\n        axis=1,\n    ).all()\n), "MMS scale up introducing unexpected maternal hemorrhages"\n'

# %% [markdown]
# # Check hemoglobin and IV iron on neonatal sepsis
#
# * Direct effect of hemoglobin on neonatal sepsis RR
# * Effect of IV iron on neonatal sepsis

# %%
# %cd /mnt/share/homes/tylerdy/vivarium_gates_mncnh
from tests.test_hemoglobin_depression_sepsis import _discover_pipeline
# Out:
# /mnt/share/homes/tylerdy/vivarium_gates_mncnh

# %%
def load_hemoglobin_neonatal_sepsis_effect(effect):  # effect="direct" or "indirect"
    file = paths.HEMOGLOBIN_EFFECTS_DATA_DIR / f"{effect}_sepsis_effects" / f"draw_{draw_num}.csv"

    data = pd.read_csv(file)
    data = data[data["location"] == location.lower()]

    if effect=="indirect":
        data = data.rename(columns={"sex_of_child": "sex"})
        age_tuples = data["age_group_id"].map(data_values.NEONATAL_AGE_GROUP_ID_BOUNDS)
        data["age_start"] = [x[0] for x in age_tuples]
        data["age_end"] = [x[1] for x in age_tuples]
        data = data.drop(columns=["age_group_id"]).rename(columns={"exposure": "parameter"})

    return data.set_index([x for x in data.columns if x!="value"])

# %%
from vivarium_gates_mncnh.data.hemoglobin_effects.hgb_birth_effect_generation import load_prepped_rrs

# %%
total_effect = (load_hemoglobin_neonatal_sepsis_effect("direct") * load_hemoglobin_neonatal_sepsis_effect("indirect")).reset_index()
total_effect = total_effect.drop(columns=["location", "draw", "age_end"]).rename(columns={"age_start": "age", "parameter": "hemoglobin", "value":"rr"})
# sanity check that total_effect is universal for sex/age
assert np.allclose(total_effect[total_effect.sex == 'Female'].drop(columns='sex').reset_index(drop=True), total_effect[total_effect.sex == 'Male'].drop(columns='sex').reset_index(drop=True)), 'total effect should be sex-universal'
assert np.allclose(total_effect[total_effect.age == 0].drop(columns='age').set_index(['sex', 'hemoglobin']), total_effect[total_effect.age == 0.01917808].drop(columns='age').set_index(['sex', 'hemoglobin'])), 'total effect should be age-universal'
# sanity check that total_effect matches helper function
assert np.allclose(total_effect[(total_effect.sex == 'Female') & (total_effect.age == 0)].drop(columns=['sex','age']), load_prepped_rrs('neonatal_sepsis').set_index(['outcome', 'risk'])[[draw]].reset_index().rename(columns={'risk':'hemoglobin', 'draw_60':'rr'}).drop(columns='outcome')), "total effect should match helper"
total_effect
# Out:
# /mnt/share/homes/tylerdy/vivarium_gates_mncnh/src/vivarium_gates_mncnh/data/hemoglobin_effects/hgb_birth_effect_generation.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   ).reset_index()  # convert beta coefficients to relative risks by exponentiating
# /mnt/share/homes/tylerdy/vivarium_gates_mncnh/src/vivarium_gates_mncnh/data/hemoglobin_effects/hgb_birth_effect_generation.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   rrs["outcome"] = outcome
#          sex       age  hemoglobin        rr
# ...

# %%
hgb_to_rr =  art.load("risk_factor.hemoglobin.neonatal_sepsis_relative_risk")[f'draw_{draw_num}'].reset_index()
hgb_to_rr = hgb_to_rr.drop(columns=["age_end", "year_start", "year_end", "affected_entity", "affected_measure"]).rename(columns={"age_start": "age", "parameter": "hemoglobin", "draw_60": "rr"})
hgb_to_rr
# Out:
#          sex       age  hemoglobin        rr
# 0     Female  0.000000    40.00000  1.051208
# 1     Female  0.000000    40.11011  1.052794
# 2     Female  0.000000    40.22022  1.054379
# 3     Female  0.000000    40.33033  1.055963
# 4     Female  0.000000    40.44044  1.057546
# ...      ...       ...         ...       ...
# 3995    Male  0.019178   149.55956  0.933280
# 3996    Male  0.019178   149.66967  0.933004
# 3997    Male  0.019178   149.77978  0.932728
# 3998    Male  0.019178   149.88989  0.932453
# 3999    Male  0.019178   150.00000  0.932178
#
# [4000 rows x 4 columns]

# %%
# sanity check that direct effect artifact matches csv
assert np.allclose(hgb_to_rr.sort_values(by=['sex', 'age', 'hemoglobin']).set_index(["sex", "age", "hemoglobin"]), load_hemoglobin_neonatal_sepsis_effect("direct").reset_index().drop(columns=["location", "draw", "age_end"]).rename(columns={"age_start": "age", "parameter": "hemoglobin", "value":"rr"}).sort_values(by=['sex', 'age', 'hemoglobin']).set_index(["sex", "age", "hemoglobin"])), 'direct csv should match artifact rr'

# %%
def round_nearest_hgb(pop, col, rounded_name):  # round col down to nearest hemoglobin value, and age_raw to age_start
    # round down to nearest hgb value
    hgb_vals = hgb_to_rr["hemoglobin"].unique()
    pop[rounded_name] = pd.cut(pop[col], np.append(hgb_vals,np.inf), labels=hgb_vals, right=False).fillna(hgb_vals[0])  # round down
    #pop[rounded_name] = pd.cut(pop[col], np.append(-np.inf,hgb_vals), labels=hgb_vals, right=True).fillna(hgb_vals[-1])  # round up
    hgb_vals = hgb_to_rr["hemoglobin"].unique()
    assert(set(pop[rounded_name].unique()).issubset(set(hgb_vals)))

    # round down to nearest age_start value
    age_vals = hgb_to_rr["age"].unique()
    pop["age"] = pd.cut(pop["age_raw"], np.append(age_vals,np.inf), labels=age_vals, right=False).fillna(age_vals[-1])
    assert(set(pop["age"].unique()).issubset(set(age_vals)))
    return pop

def get_hgb_neonatal_sepsis_data(sim, scenario):  # get pop with pipline rr, pipeline csmr, and expected rr (from artifact based on hgb/age/sex) - values associated with previous timestep
    pop = sim.get_population(
        [
            data_values.COLUMNS.SEX_OF_CHILD,
            data_values.COLUMNS.PREGNANCY_OUTCOME,
            data_values.COLUMNS.CHILD_ALIVE,
            data_values.COLUMNS.CHILD_AGE,
            data_values.COLUMNS.CHILD_CAUSE_OF_DEATH,
            data_values.COLUMNS.IV_IRON_INTERVENTION,
            data_values.COLUMNS.ANC_ATTENDANCE,
            data_values.COLUMNS.TESTED_HEMOGLOBIN,
            data_values.COLUMNS.TESTED_FERRITIN,
            data_values.COLUMNS.ORAL_IRON_INTERVENTION,
        ]
    ).rename(columns={"sex_of_child": "sex", "child_age": "age_raw"})

    #pop["hgb_cur"] = sim.get_population('hemoglobin_exposure_for_non_loglinear_riskeffect')  # current hgb (for the previous step) NOTE removed this but haven't re-run
    pop["hgb_birth"] = birth_hgb[scenario]  # birth hgb (before postpartum_hemorrhage step)
    
    # Capture the hemoglobin sepsis RR *at snapshot time*: it is a child_age/sex/hgb
    # lookup, so it must be read while the sim is at this step (the module-scoped sim
    # later advances to the ppd step, where child_age no longer matches this step).
    rr_name = _discover_pipeline(
        sim, must_contain=["neonatal_sepsis", "relative_risk", "hemoglobin"]
    )
    sepsis_hgb_rr = sim.get_population(rr_name)

    pop["csmr"] = sim.get_population("neonatal_sepsis_and_other_neonatal_infections.cause_specific_mortality_risk")

    #pop = round_nearest_hgb(pop, 'hgb_cur', 'hemoglobin')
    pop = round_nearest_hgb(pop, 'hgb_birth', 'hemoglobin')

    pop = pd.merge(pop, hgb_to_rr, on=['sex', 'age', 'hemoglobin'], how='left').rename(columns={"rr": "expected_rr_direct"})
    pop = pd.merge(pop, total_effect, on=['sex', 'age', 'hemoglobin'], how='left').rename(columns={"rr": "expected_rr_total"})

    pop["rr_direct"] = sepsis_hgb_rr

    return pop

# %%
# NOTE: checking this within 1% as it does not match exactly, which may be due to this ticket https://jira.ihme.washington.edu/browse/MIC-7463
# After this is investigated further, if changes are made this test could potentially be adjusted

scen_pops_enn = {}
scen_pops_lnn = {}

for scenario in scenarios:
    sim = sims[scenario]

    # CHECK: direct effect of hemoglobin on neonatal sepsis
    assert sim._clock.step_name == 'early_neonatal_mortality', "step should be ENN"
    sim.step()

    assert sim._clock.step_name == 'late_neonatal_mortality', "step should be LNN"
    enn_pop = get_hgb_neonatal_sepsis_data(sim, scenario)  # the pipelines evaluated reflect ENN when step=LNN

    sim.step()
    lnn_pop = get_hgb_neonatal_sepsis_data(sim, scenario)  # the pipelines evaluated reflect LNN when step=PPD
    
    if scenario in ['baseline', 'anemia_screening_and_iv_iron_scaleup']:
        # Exclude those who received IFA for the first time at the late pregnancy visit. 
        # The change in hemoglobin between scenarios for this group will not reflect the expected IV iron effect size due to a modeling nuance.
        enn_pop = enn_pop.loc[~((enn_pop.anc_attendance=='later_pregnancy_only')&(enn_pop.oral_iron_intervention=='ifa'))] 
        lnn_pop = lnn_pop.loc[~((lnn_pop.anc_attendance=='later_pregnancy_only')&(lnn_pop.oral_iron_intervention=='ifa'))] 
        scen_pops_enn[scenario] = enn_pop
        scen_pops_lnn[scenario] = lnn_pop

    assert np.all(((enn_pop["rr_direct"]-enn_pop["expected_rr_direct"]) / enn_pop["expected_rr_direct"]).abs() < .02), "Expected rr should match pipeline value" # <2% difference
    assert np.all(((lnn_pop["rr_direct"]-lnn_pop["expected_rr_direct"]) / lnn_pop["expected_rr_direct"]).abs() < .02), "Expected rr should match pipeline value" # <2% difference

# %%
enn_baseline = scen_pops_enn['baseline']
enn_iv_iron = scen_pops_enn['anemia_screening_and_iv_iron_scaleup']
off_by = np.abs(1 - ((enn_baseline['csmr'] / enn_iv_iron['csmr']) / (enn_baseline['expected_rr_total'] / enn_iv_iron['expected_rr_total'])))
enn_not_close_idx = off_by >= .02
enn_not_close = enn_iv_iron[enn_not_close_idx]
display(off_by.describe())
display(f"{enn_not_close_idx.sum()} / {(enn_iv_iron['iv_iron_intervention'] == 'covered').sum()} simulants covered by IV iron are not close")
enn_not_close
# Out:
# count    53152.000000
# mean         0.004845
# std          0.024101
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          0.523138
# dtype: float64
# '2855 / 3787 simulants covered by IV iron are not close'
#           sex pregnancy_outcome  child_alive   age_raw child_cause_of_death  \
# 31       Male        live_birth         True  0.009589             not_dead
# 52       Male        live_birth         True  0.009589             not_dead
# 68     Female        live_birth         True  0.009589             not_dead
# 83     Female        live_birth         True  0.009589             not_dead
# 129      Male        live_birth         True  0.009589             not_dead
# ...       ...               ...          ...       ...                  ...
# 59911    Male        live_birth         True  0.009589             not_dead
# 59913  Female        live_birth         True  0.009589             not_dead
# ...

# %%
enn_baseline[enn_not_close_idx]
# Out:
#           sex pregnancy_outcome  child_alive   age_raw child_cause_of_death  \
# 31       Male        live_birth         True  0.009589             not_dead
# 52       Male        live_birth         True  0.009589             not_dead
# 68     Female        live_birth         True  0.009589             not_dead
# 83     Female        live_birth         True  0.009589             not_dead
# 129      Male        live_birth         True  0.009589             not_dead
# ...       ...               ...          ...       ...                  ...
# 59911    Male        live_birth         True  0.009589             not_dead
# 59913  Female        live_birth         True  0.009589             not_dead
# 59923  Female        live_birth         True  0.009589             not_dead
# 59961    Male        live_birth         True  0.009589             not_dead
# 59994  Female        live_birth         True  0.009589             not_dead
#
# ...

# %%
enn_iv_iron[enn_not_close_idx]
# Out:
#           sex pregnancy_outcome  child_alive   age_raw child_cause_of_death  \
# 31       Male        live_birth         True  0.009589             not_dead
# 52       Male        live_birth         True  0.009589             not_dead
# 68     Female        live_birth         True  0.009589             not_dead
# 83     Female        live_birth         True  0.009589             not_dead
# 129      Male        live_birth         True  0.009589             not_dead
# ...       ...               ...          ...       ...                  ...
# 59911    Male        live_birth         True  0.009589             not_dead
# 59913  Female        live_birth         True  0.009589             not_dead
# 59923  Female        live_birth         True  0.009589             not_dead
# 59961    Male        live_birth         True  0.009589             not_dead
# 59994  Female        live_birth         True  0.009589             not_dead
#
# ...

# %%
(enn_iv_iron[enn_not_close_idx]['hgb_birth'] - enn_baseline[enn_not_close_idx]['hgb_birth']).value_counts()
# Out:
# hgb_birth
# 21.659714    2336
# 21.659714     510
# 21.659714       9
# Name: count, dtype: int64

# %%
def get_col_by_hgb_bin(pop, q, col, agg_func, strats=[]):  
    with np.errstate(under='ignore'):
        pop["hgb_bin"] = pd.qcut(pop['hgb_birth'], q)
    to_group = pop.drop(columns=[x for x in pop.columns if x not in strats + [col, 'hgb_bin']])
    return to_group.groupby([x for x in to_group.columns if x != col]).agg(agg_func).rename(columns={col: f"{col}_{agg_func}"}).reset_index()

# %%
# plot value by bin, relative to TMREL, vs expected from art/data
def plot_binned_ratios(pop, step_and_filter, q):  # pop should be baseline pop to match x label
    mr_ratio = get_col_by_hgb_bin(pop, q, 'mr_ratio', 'mean')
    bins = mr_ratio['hgb_bin']
    mr_ratio = mr_ratio['mr_ratio_mean']
    total_rr_ratio = get_col_by_hgb_bin(pop, q, 'total_rr_ratio', 'mean')['total_rr_ratio_mean']

    # total effect plots:
    fig, ax = plt.subplots()
    ax.bar([(x.right + x.left) / 2 for x in bins], mr_ratio, width=[x.right - x.left for x in bins], label="Observed (bin mean)", alpha=.5)
    ax.bar([(x.right + x.left) / 2 for x in bins], total_rr_ratio, width=[x.right - x.left for x in bins], label="Expected (bin mean)", alpha=.5)

    plt.xlabel('Hemoglobin Exposure (baseline scenario)')
    plt.ylabel('RR')
    plt.title(f'{step_and_filter}: Observed and Expected total effect RRs')
    plt.legend(loc=(1.01, .01))
    plt.grid()
    plt.ylim(bottom=np.floor((np.min([mr_ratio.min(), total_rr_ratio.min()]) - .001)/ 0.05) * 0.05)
    plt.show()

    fig, ax = plt.subplots()
    ax.bar([(x.right + x.left) / 2 for x in bins], mr_ratio / total_rr_ratio, width=[x.right - x.left for x in bins], alpha=.5)
    plt.xlabel('Hemoglobin Exposure (baseline scenario)')
    plt.ylabel('RR relative to expected')
    plt.title(f'{step_and_filter}: Observed / expected total effect RR')
    plt.grid()
    plt.ylim(bottom=np.floor(((mr_ratio / total_rr_ratio).min() - .001)/ 0.05) * 0.05)
    plt.show()

    rr_direct = get_col_by_hgb_bin(pop, q, 'rr_direct', 'mean')['rr_direct_mean']
    expected_rr_direct = get_col_by_hgb_bin(pop, q, 'expected_rr_direct', 'mean')['expected_rr_direct_mean']

    # indirect effect plots:
    fig, ax = plt.subplots()
    ax.bar([(x.right + x.left) / 2 for x in bins], mr_ratio / rr_direct, width=[x.right - x.left for x in bins], label="Observed (total / direct, bin mean)", alpha=.5)
    ax.bar([(x.right + x.left) / 2 for x in bins], total_rr_ratio/ expected_rr_direct, width=[x.right - x.left for x in bins], label="Expected (total / direct, bin mean)", alpha=.5)

    plt.xlabel('Hemoglobin Exposure (baseline scenario)')
    plt.ylabel('RR')
    plt.title(f'{step_and_filter}: Observed and Expected indirect effects RRs')
    plt.legend(loc=(1.01, .01))
    plt.grid()
    plt.ylim(bottom=np.floor((np.min([(mr_ratio / rr_direct).min(), (total_rr_ratio/ expected_rr_direct).min()]) - .001)/ 0.05) * 0.05)
    plt.show()

    fig, ax = plt.subplots()
    ax.bar([(x.right + x.left) / 2 for x in bins], (mr_ratio / rr_direct) / (total_rr_ratio/ expected_rr_direct), width=[x.right - x.left for x in bins], alpha=.5)
    plt.xlabel('Hemoglobin Exposure (baseline scenario)')
    plt.ylabel('RR relative to expected')
    plt.title(f'{step_and_filter}: Observed / expected indirect effect RR')
    plt.grid()
    plt.ylim(bottom=np.floor((((mr_ratio / rr_direct) / (total_rr_ratio/ expected_rr_direct)).min() - .001)/ 0.05) * 0.05)
    plt.show()

# %%
import pickle

# %%
# save population tables in case of connection/processing issues
with open("neonatal_step_pop_tables_60k.pkl", "wb") as file:
    pickle.dump([scen_pops_enn, scen_pops_lnn], file)

# %%
with open('/mnt/share/homes/tylerdy/vivarium_gates_mncnh/neonatal_step_pop_tables_60k.pkl', 'rb') as file:
    loaded_data = pickle.load(file)
scen_pops_enn = loaded_data[0]
scen_pops_lnn = loaded_data[1]

# %%
# CHECK: IV iron on nn sepsis total effect
def copy(pop):
    return {key: df.copy() for key, df in pop.items()}

for step, pop in {'early_neonatal_mortality': scen_pops_enn, 'late_neonatal_mortality': scen_pops_lnn}.items():
    filters = {  # filter both scen pop tables by status in iv_iron_intervention scen
        'iv_iron_recvd': pop['anemia_screening_and_iv_iron_scaleup'].iv_iron_intervention == 'covered',
        #'non_anc': pop['anemia_screening_and_iv_iron_scaleup'].anc_attendance == 'none',  # non anc do not receive IV iron so this is not relevant
    }  

    orig_pop = copy(pop)

    for fname, filter in filters.items():
        pop = copy(orig_pop)  # reset to pre-filtered pop
        pop['baseline'] = pop['baseline'][filter]
        pop['anemia_screening_and_iv_iron_scaleup'] = pop['anemia_screening_and_iv_iron_scaleup'][filter]

        # assert that IFA/ANC filter was applied when pop tables were created
        assert len(pop['baseline'].loc[(pop['baseline'].anc_attendance=='later_pregnancy_only')&(pop['baseline'].oral_iron_intervention=='ifa')]) == 0, 'simulants that received IFA for the first time at late pregnancy visit should be excluded'
        assert len(pop['anemia_screening_and_iv_iron_scaleup'].loc[(pop['anemia_screening_and_iv_iron_scaleup'].anc_attendance=='later_pregnancy_only')&(pop['anemia_screening_and_iv_iron_scaleup'].oral_iron_intervention=='ifa')]) == 0, 'simulants that received IFA for the first time at late pregnancy visit should be excluded'
        
        baseline_sepsis_mr = pop['baseline']['csmr']
        baseline_total_sepsis_rr = pop['baseline']['expected_rr_total']
        anemia_iv_iron_sepsis_mr = pop['anemia_screening_and_iv_iron_scaleup']['csmr']
        anemia_iv_iron_total_sepsis_rr = pop['anemia_screening_and_iv_iron_scaleup']['expected_rr_total']

        mr_ratio = anemia_iv_iron_sepsis_mr / baseline_sepsis_mr
        pop['baseline']['mr_ratio'] = mr_ratio
        total_rr_ratio = anemia_iv_iron_total_sepsis_rr / baseline_total_sepsis_rr
        pop['baseline']['total_rr_ratio'] = total_rr_ratio
        pop['baseline']['mr_total_rr_ratio'] = mr_ratio / total_rr_ratio

        plot_binned_ratios(
            pop['baseline'],
            f'{step}, {fname}',
            30
        )
        display(f'Total effect RR relative to expected, simulant-level ({step}, {fname})')
        display((mr_ratio / total_rr_ratio).describe())
# Out:
# 'Total effect RR relative to expected, simulant-level (early_neonatal_mortality, iv_iron_recvd)'
# count    3787.000000
# mean        1.027592
# std         0.094907
# min         0.656540
# 25%         0.976124
# 50%         1.015815
# 75%         1.077782
# max         1.509356
# dtype: float64
# 'Total effect RR relative to expected, simulant-level (late_neonatal_mortality, iv_iron_recvd)'
# count    3787.000000
# mean        1.012993
# std         0.077731
# min         0.527186
# 25%         0.981066
# 50%         1.000000
# 75%         1.042498
# max         1.788911
# dtype: float64

# %% [markdown]
# # Postpartum depression

# %%
# Step to postpartum depression
for scenario in scenarios:
    sim = sims[scenario]
    assert sim._clock.step_name == 'postpartum_depression', "step should be PPD"

    # Step past postpartum depression
    sim.step()
    plot_outcome_incidence_effects('postpartum_depression')

# %%
# CHECK: Hemoglobin effect on postpartum depression incidence
plot_outcome_incidence_effects('postpartum_depression')
