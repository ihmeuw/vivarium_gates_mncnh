# %%
from vivarium import Artifact, InteractiveContext
import pandas as pd, numpy as np, os

# %%
! pip list | grep vivarium

# [software verion + hash . date]
# Out:
# vivarium                                 4.0.3
# vivarium_build_utils                     3.3.4
# vivarium_cluster_tools                   3.1.5.dev18+gf4de47f50
# vivarium-config-tree                     5.0.6
# vivarium-dependencies                    1.2.4
# vivarium_gates_mncnh                     37.2.dev15+gede86b92c  /mnt/share/homes/tylerdy/vivarium_gates_mncnh
# vivarium_gbd_access                      5.0.16
# vivarium_inputs                          7.2.9
# vivarium_public_health                   5.0.2
# vivarium_testing_utils                   0.5.5

# %%
! pip freeze | grep vivarium
# Out:
# vivarium==4.0.3
# vivarium-config-tree==5.0.6
# vivarium-dependencies==1.2.4
# vivarium_build_utils==3.3.4
# vivarium_cluster_tools @ git+https://github.com/ihmeuw/vivarium_cluster_tools.git@f4de47f502e5393420945f173478e250e47714bd
# -e git+https://github.com/ihmeuw/vivarium_gates_mncnh.git@f31621cfec4d3e3c0a0c51db048331948968a235#egg=vivarium_gates_mncnh
# vivarium_gbd_access==5.0.16
# vivarium_inputs==7.2.9
# vivarium_public_health==5.0.2
# vivarium_testing_utils==0.5.5

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from vivarium import InteractiveContext, Artifact

# %%
import vivarium_gates_mncnh
from vivarium.framework.configuration import build_model_specification
from pathlib import Path

path = Path(vivarium_gates_mncnh.__file__).parent / 'model_specifications/model_spec.yaml'
custom_model_specification = build_model_specification(path)
del custom_model_specification.configuration.observers
# custom_model_specification.configuration.input_data.input_draw_number = 60
custom_model_specification.configuration.population.population_size = 20_000 * 10

artifact_path = custom_model_specification.configuration.input_data.artifact_path
art = Artifact(artifact_path)

artifact_path
# Out:
# '/mnt/team/simulation_science/pub/models/vivarium_gates_mncnh/artifacts/model37.0/ethiopia.hdf'

# %%
draw_num = custom_model_specification.configuration.input_data.input_draw_number
draw = 'draw_' + str(draw_num)
draw
# Out:
# 'draw_60'

# %%
sim = InteractiveContext(custom_model_specification)
# Out:
# 2026-07-28 07:18:36.539 | INFO     | simulation_1-artifact_manager:80 - Running simulation from artifact located at /mnt/team/simulation_science/pub/models/vivarium_gates_mncnh/artifacts/model37.0/ethiopia.hdf.
# 2026-07-28 07:18:36.540 | INFO     | simulation_1-artifact_manager:81 - Artifact base filter terms are ['draw == 60'].
# 2026-07-28 07:18:36.540 | INFO     | simulation_1-artifact_manager:82 - Artifact additional filter terms are None.
# 2026-07-28 07:18:59.289 | WARNING  | simulation_1-results_manager:409 - Specified excluded stratifications are already not included by default: ['stillbirth', 'partial_term']
# 2026-07-28 07:18:59.291 | WARNING  | simulation_1-results_manager:409 - Specified excluded stratifications are already not included by default: ['stillbirth', 'partial_term']
# 2026-07-28 07:18:59.409 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_factor.hemoglobin' configured, but didn't build lookup table 'exposure' during setup.
# 2026-07-28 07:18:59.410 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_factor.hemoglobin' configured, but didn't build lookup table 'ensemble_distribution_weights' during setup.
# 2026-07-28 07:18:59.411 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_factor.hemoglobin' configured, but didn't build lookup table 'exposure_standard_deviation' during setup.
# 2026-07-28 07:18:59.412 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_factor.low_birth_weight_and_short_gestation' configured, but didn't build lookup table 'exposure' during setup.
# 2026-07-28 07:18:59.412 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_factor.low_birth_weight_and_short_gestation' configured, but didn't build lookup table 'ensemble_distribution_weights' during setup.
# 2026-07-28 07:18:59.413 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_factor.low_birth_weight_and_short_gestation' configured, but didn't build lookup table 'exposure_standard_deviation' during setup.
# 2026-07-28 07:18:59.413 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_factor.low_birth_weight_and_short_gestation' configured, but didn't build lookup table 'birth_exposure' during setup.
# 2026-07-28 07:18:59.414 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_effect.low_birth_weight_and_short_gestation_on_cause.all_causes.all_cause_mortality_risk' configured, but didn't build lookup table 'relative_risk' during setup.
# 2026-07-28 07:18:59.414 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_effect.low_birth_weight_and_short_gestation_on_cause.neonatal_sepsis_and_other_neonatal_infections.cause_specific_mortality_risk' configured, but didn't build lookup table 'relative_risk' during setup.
# 2026-07-28 07:18:59.415 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_effect.low_birth_weight_and_short_gestation_on_cause.neonatal_preterm_birth_with_rds.cause_specific_mortality_risk' configured, but didn't build lookup table 'relative_risk' during setup.
# 2026-07-28 07:18:59.415 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_effect.low_birth_weight_and_short_gestation_on_cause.neonatal_preterm_birth_without_rds.cause_specific_mortality_risk' configured, but didn't build lookup table 'relative_risk' during setup.
# 2026-07-28 07:18:59.416 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'risk_effect.low_birth_weight_and_short_gestation_on_cause.neonatal_encephalopathy_due_to_birth_asphyxia_and_trauma.cause_specific_mortality_risk' configured, but didn't build lookup table 'relative_risk' during setup.
# 2026-07-28 07:18:59.416 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'non_log_linear_risk_effect.hemoglobin_on_cause.maternal_hemorrhage.incidence_risk' configured, but didn't build lookup table 'population_attributable_fraction' during setup.
# 2026-07-28 07:18:59.417 | WARNING  | simulation_1-lookup_table_manager:85 - Component 'non_log_linear_risk_effect.hemoglobin_on_cause.maternal_sepsis_and_other_maternal_infections.incidence_risk' configured, but didn't build lookup table 'population_attributable_fraction' during setup.
# 2026-07-28 07:18:59.417 | INFO     | simulation_1-results_context:131 - The following stratifications are registered but not used by any observers:
# ['ferritin_screening_coverage', 'hemoglobin_screening_coverage', 'sex']

# %%
sim_step_name = sim.list_components()['risk_factor.hemoglobin']._sim_step_name
sim_step_name()
# Out:
# 'first_trimester_anc'

# %%
def get_pop_with_pregnancy_duration(sim):
    lbwsg_birth_exposure = sim.get_population(
        'low_birth_weight_and_short_gestation.birth_exposure'
    )
    pop = sim.get_population(
        ['pregnancy_outcome', 'gestational_age.exposure', 'pregnancy_duration']
    )
    pop['gestational_age_birth_exposure'] = lbwsg_birth_exposure['gestational_age']
    pop = pop.rename(columns={
        'gestational_age.exposure': 'gestational_age_exposure_column',
    })
    return pop[['pregnancy_outcome', 'gestational_age_exposure_column', 'gestational_age_birth_exposure', 'pregnancy_duration']]

# %%
pop = get_pop_with_pregnancy_duration(sim)
pregnancy_duration = pop.pregnancy_duration
# https://vivarium-research.readthedocs.io/en/latest/models/other_models/pregnancy/gbd_2021_mncnh/index.html#assign-gestational-age-at-end-of-pregnancy-abortion-miscarriage-ectopic-pregnancies
assert (pop[pop.pregnancy_outcome == 'partial_term'].pregnancy_duration >= pd.Timedelta(days=(6 * 7))).all(), "abortion/miscarriage/ectopic pregnancies with duration less than 6 weeks"
assert (pop[pop.pregnancy_outcome == 'partial_term'].pregnancy_duration < pd.Timedelta(days=(24 * 7))).all(), "abortion/miscarriage/ectopic pregnancies with duration greater than 24 weeks"

# %%
while sim_step_name() != "ultrasound":
    assert np.allclose(
        pop.gestational_age_birth_exposure,
        pop.pregnancy_duration / pd.Timedelta(days=7)
    ), "pregnancy duration and gestational age disagree!"

    pop = get_pop_with_pregnancy_duration(sim)
    assert pop.gestational_age_exposure_column.isnull().all(), "gestational age column assigned pre-ultrasound"
    sim.step()

# Go past ultrasound step
sim.step()
# Out:
# 2026-07-28 07:19:31.278 | INFO     | simulation_1 - vivarium.framework.engine:280 - 2025-01-01 00:00:00
# 2026-07-28 07:20:05.256 | INFO     | simulation_1 - vivarium.framework.engine:280 - 2025-01-02 00:00:00
# 2026-07-28 07:20:20.094 | INFO     | simulation_1 - vivarium.framework.engine:280 - 2025-01-03 00:00:00
# 2026-07-28 07:20:36.147 | INFO     | simulation_1 - vivarium.framework.engine:280 - 2025-01-04 00:00:00
# 2026-07-28 07:20:55.239 | INFO     | simulation_1 - vivarium.framework.engine:280 - 2025-01-05 00:00:00

# %%
pop = get_pop_with_pregnancy_duration(sim)
pop
# Out:
#        pregnancy_outcome  gestational_age_exposure_column  \
# 0             live_birth                        39.424972
# 1           partial_term                        18.140006
# 2           partial_term                        15.821030
# 3           partial_term                        21.898284
# 4             live_birth                        39.499262
# ...                  ...                              ...
# 199995      partial_term                        11.366076
# 199996        live_birth                        38.389322
# 199997        live_birth                        41.166426
# 199998        live_birth                        38.648815
# 199999      partial_term                        20.197873
#
#         gestational_age_birth_exposure          pregnancy_duration
# 0                            39.424972 275 days 23:23:43.000545897
# 1                            18.140006 126 days 23:31:15.581246692
# 2                            15.821030 110 days 17:55:58.891360316
# 3                            21.898284 153 days 06:54:42.088881381
# 4                            39.499262 276 days 11:52:33.669714005
# ...                                ...                         ...
# 199995                       11.366076  79 days 13:30:02.599728428
# 199996                       38.389322 268 days 17:24:21.911723441
# 199997                       41.166426 288 days 03:57:34.738560095
# 199998                       38.648815 270 days 13:00:03.610027468
# 199999                       20.197873 141 days 09:14:33.816255881
#
# [200000 rows x 4 columns]

# %%
assert pop.pregnancy_duration[pop.pregnancy_outcome == 'partial_term'].equals(pregnancy_duration[pop.pregnancy_outcome == 'partial_term']), "pregnancy duration changed for abortion/miscarriage/ectopic pregnancies"

# %%
assert np.allclose(
    pop.gestational_age_birth_exposure,
    pop.pregnancy_duration / pd.Timedelta(days=7)
), "pregnancy duration and gestational age disagree!"

# %%
assert (
    pop.gestational_age_birth_exposure
    ==
    pop.gestational_age_exposure_column
).all(), "gestational age disagrees between value pipeline and state table!"

# %%
(pop[pop.pregnancy_outcome == 'live_birth'].pregnancy_duration / pd.Timedelta(days=7)).describe()
# Out:
# count    109556.000000
# mean         38.061470
# std           2.376763
# min          19.939834
# 25%          37.324414
# 50%          38.353344
# 75%          39.487742
# max          42.074507
# Name: pregnancy_duration, dtype: float64

# %%
(pop[pop.pregnancy_outcome == 'stillbirth'].pregnancy_duration / pd.Timedelta(days=7)).describe()
# Out:
# count    3125.000000
# mean       38.125192
# std         2.273871
# min        24.204384
# 25%        37.347866
# 50%        38.379202
# 75%        39.475380
# max        42.064467
# Name: pregnancy_duration, dtype: float64

# %%
# The 'risk specific shift' is the amount to delete
# https://github.com/ihmeuw/vivarium_gates_mncnh/blob/bdffaa88cb94eaa53a97df75be2e307dfd52c25e/src/vivarium_gates_mncnh/data/loader.py#L1326-L1335
ifa_ga_deletion = art.load('risk_factor.iron_folic_acid_supplementation.risk_specific_shift')
assert (ifa_ga_deletion.groupby('affected_entity').nunique() == 1).all().all()
ifa_ga_deletion = ifa_ga_deletion.groupby('affected_entity').first().loc['gestational_age'][draw]
ifa_ga_deletion
# Out:
# 0.0641060920641154

# %%
# https://vivarium-research.readthedocs.io/en/latest/models/risk_exposures/low_birthweight_short_gestation/gbd_2021/index.html#converting-gbd-s-categorical-exposure-distribution-to-a-continuous-exposure-distribution
# NOTE: This minimum is on the LBWSG category sampled, but baseline IFA deletion decreases GA
assert (pop[pop.pregnancy_outcome == 'live_birth'].pregnancy_duration >= pd.Timedelta(days=((20 - ifa_ga_deletion) * 7))).all(), "live birth pregnancies with duration less than 20 weeks minus baseline IFA deletion"

# %%
# https://vivarium-research.readthedocs.io/en/latest/models/other_models/pregnancy/gbd_2021_mncnh/index.html#assign-birthweight-and-gestational-age-at-end-of-pregnancy-live-births-and-stillbirths
assert (pop[pop.pregnancy_outcome == 'stillbirth'].pregnancy_duration >= pd.Timedelta(days=((24 - ifa_ga_deletion) * 7))).all(), "stillbirth pregnancies with duration less than 24 weeks minus baseline IFA deletion"
